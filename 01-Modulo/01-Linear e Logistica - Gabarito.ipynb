# %% [markdown]
# # Aprendizado Profundo - UFMG
#
# ## Preâmbulo
#
# O código abaixo consiste dos imports comuns. Além do mais, configuramos as imagens para ficar de um tamanho aceitável e criamos algumas funções auxiliares. No geral, você pode ignorar a próxima célula.

# %%
# -*- coding: utf8

import matplotlib.pyplot as plt
import torch
import numpy as np

plt.rcParams['figure.figsize']  = (18, 10)
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['axes.titlesize']  = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['lines.linewidth'] = 4
torch.set_printoptions(precision=10)

# %%
plt.ion()

plt.style.use('seaborn-colorblind')
plt.rcParams['figure.figsize']  = (12, 8)

# %% [markdown]
# Para testar o resultado dos seus algoritmos vamos usar o módulo testing do numpy.

# %%
from numpy.testing import assert_equal
from numpy.testing import assert_almost_equal
from numpy.testing import assert_array_almost_equal

# %% [markdown]
# ## Regressão Linear e Logística from Scratch
#
# Para brincar um pouco mais com essa diferenciação automatica, presente em frameworks como pytorch e mxnet, nesta aula vamos implementar a regressão linear e logística do zero. Vamos fazer duas versões de cada:
#
# 1. Derivando na mão, não é complicado.
# 2. Derivando com autograd de pytorch

# %% [markdown]
# ## Conjunto de Problemas 1: Mais Derivadas

# %% [markdown]
# Antes de entrar na regressão, vamos brincar um pouco de derivadas dentro de funções. Dado dois números `x` and `y`, implemente a função `log_exp` que retorna:
#
# $$-\log\left(\frac{e^x}{e^x+e^y}\right)$$

# %%
def log_exp(x, y):
    return (-torch.log(torch.exp(x) / (torch.exp(x) + torch.exp(y)))).double()

# %% [markdown]
# 1. Abaixo vamos testar o seu código com algumas entradas simples.

# %%
x, y = torch.tensor([2.0]), torch.tensor([3.0])
z = log_exp(x, y)
z
# Out:
# tensor([1.3132617474], dtype=torch.float64)

# %%
# Teste. Não apague
assert_almost_equal(1.31326175, z.numpy())

# %% [markdown]
# 2. A função a seguir computa $\partial z/\partial x$ e $\partial z/\partial y$ usando `autograd`.

# %%
# O argumento funcao_forward é uma função python. Será a sua log_exp.
# A ideia aqui é deixar claro a ideia de forward e backward propagation, depois
# de avaliar a função chamamos backward e temos as derivadas.
def grad(funcao_forward, x, y):
    x.requires_grad_(True)
    y.requires_grad_(True)
    z = funcao_forward(x, y)
    z.backward()
    return x.grad, y.grad

# %% [markdown]
# Testando

# %%
x, y = torch.tensor([2.0], dtype = torch.double) ,torch.tensor([3.0], dtype = torch.double)
dx, dy = grad(log_exp, x, y)

# %%
assert_almost_equal(-0.7310586, dx.numpy())
assert_almost_equal(0.7310586, dy.numpy())

# %% [markdown]
# 4. Agora teste com números maiores, algum problema?

# %%
x, y = torch.tensor([400.0]).double() ,torch.tensor([800.0]).double()
grad(log_exp, x, y)
# Out:
# (tensor([nan], dtype=torch.float64), tensor([nan], dtype=torch.float64))

# %% [markdown]
# 5. Pense um pouco sobre o motivo do erro acima. Usando as propriedade de logaritmos, é possível fazer uma função mais estável. Abaixo segue a implementação da mesma. O problema aqui é que o exponencial "explode" quando x ou y são muito grandes. Este [link](http://www.wolframalpha.com/input/?i=log[e%5Ex+%2F+[e%5Ex+%2B+e%5Ey]]) pode ajudar.

# %%
x, y = torch.tensor([400.0], dtype = torch.double) ,torch.tensor([800.0], dtype = torch.double)
def stable_log_exp(x, y):
    return torch.log(1+torch.exp(y-x))

dx, dy = grad(stable_log_exp, x, y)

# %%
stable_log_exp(x, y)
# Out:
# tensor([400.], dtype=torch.float64, grad_fn=<LogBackward>)

# %%
# Teste. Não apague
assert_equal(-1, dx.numpy())
assert_equal(1, dy.numpy())

# %% [markdown]
# O exemplo acima mostra um pouco de problemas de estabilidade númerica. Às vezes é melhor usar versões alternativas de funções. Isto vai ocorrer quando você ver vários nans na sua frente :-) Claro, estamos assumindo que existe uma outra função equivalente que é mais estável para o computador.

# %% [markdown]
# ## Conjunto de Problemas 2: Regressão Linear
#
# Agora, vamos explorar uma regressão linear. Embora não vamos fazer uso da logexp acima, a ideia de derivar parcialmente dentro de funções pode nos ajudar. Lembrando da regressão linear, inicialmente temos um conjunto observações representadas como tuplas $(\mathbf{x}_i, y_i)$. Aqui, $\mathbf{x}_i$ é um vetor de atributos. Vamo forçar $\mathbf{x}_{i0} = 1$, capturando assim o intercepto. Além do mais, $\mathbf{x}_{ij}$ quando $j\neq 0$, são os outros atributos de entrada. $y_i$ um valor real representando uma resposta. Nossa regressão visa capturar:
#
# $$y_i = 1 + \theta_1 x_{i1} + \theta_2 x_{i2} + \cdots + \theta_k x_{if}$$
#
# Lembrando da regressão linear multivariada, podemos representar as equações como uma multiplicação de uma matriz com um vetor
#
# ![](./figs/linear.png)
#
# 7. Crie uma função de previsao. A mesma recebe uma matrix $\mathbf{X}$ e um vetor de parâmetros $\theta$. Sua função deve retornar um vetor de previsões para cada linha de $\mathbf{X}$. Não use nenhum laço!!

# %%
def previsao(X, theta):
    return torch.matmul(X, theta.float())

# %% [markdown]
# **Erros quadrados**. Para aprender os parâmetros ótimos da regressão linear, precisamos fazer uso de um modelo de erros quadrados. Em particular nosso objetico é aprender os parâmetros que minimizam a função:
#
# $$L(\mathbf{\theta}) = n^{-1} \sum_i ({\hat{y}_i - y_i})^2$$
#
# Onde $\hat{y}_i$ é uma previsão (vêm da sua função python acima). $y_i$ é o valor real dos dados.
#
# 8. Implemente uma função para a média dos os erros quadrados.

# %%
def media_erros_quadrados(X, theta, y):
    pred = previsao(X, theta) 
    return torch.pow(pred- y, 2).mean()

# %% [markdown]
# 9. Agora, crie uma função que deriva o erro acima. A função deve usar o autograd do pytorch (função backward). Lembre-se que temos um vetor de parâmetros $\theta$. Por sorte, você pode fazer derivadas de tais vetores também.

# %%
def derivada_torch(X, theta, y): #Lembre que o theta passado devera ser uma variavel com requires_grad == True
    e = media_erros_quadrados(X, theta, y)
    e.backward()
    return theta.grad

# %% [markdown]
# 10. Esta versão não usa autograd. As derivadas são implementadas do zero. Nos [slides](https://docs.google.com/presentation/d/1bz3G3fEohNtvERKSDtThfGPYOjF83Fzy2yHPdCAlFZw/edit#slide=id.g584f66d2ae_3_74) do link explicamos como fazer tal operação.

# %%
def derivada_navera(X, theta, y):
    return ((torch.matmul(X, theta) - y) * X.T).mean(axis=1)

# %% [markdown]
# 11. Por fim, otimize sua função usando o algoritmo de gradiente descendente abaixo.

# %%
def gd(d_fun, loss_fun, X, y, lambda_=0.01, tol=0.00001, max_iter=10000):
    '''
    Executa Gradiente Descendente. Aqui:
    
    Parâmetros
    ----------
    d_fun : é uma função de derivadas
    loss_fun : é uma função de perda
    X : é um vetor de fatores explanatórios.
        Copie seu código de intercepto da primeira aula.
        para adicionar o intercepto em X.
    y : é a resposta
    lambda : é a taxa de aprendizad
    tol : é a tolerância, define quando o algoritmo vai parar.
    max_ter : é a segunda forma de parada, mesmo sem convergir
              paramos depois de max_iter iterações.
    '''
    theta = torch.randn(X.shape[1])
    theta.requires_grad_(True)
    
    print('Iter {}; theta = '.format(0), theta)
    
    old_err_sq = np.inf
    i = 0
    while True:
        # Computar as derivadas
                
        theta.requires_grad_(True)  #Necessario pois ao final, theta recebe o theta novo, que não tem requires_grad == True
        grad = d_fun(X,theta,y)

        # Atualizar
        with torch.no_grad(): 
            theta_novo = theta - lambda_ * grad
        
        #Parar quando o erro convergir
        err_sq = loss_fun(X, theta, y)
        if torch.abs(old_err_sq - err_sq) <= tol:
            break
        
         #Atualizar parâmetros e erro
        theta = theta_novo
        old_err_sq = err_sq
        
        # Informação de debug
        print('Iter {}; theta = '.format(i+1), theta)
        i += 1
        if i == max_iter:
            break
        
    return theta

# %%
# Para testes, não apague!!!
X = torch.zeros(1000, 2)
X[:, 0] = 1.0
X[:, 1] = torch.randn(1000)

theta_0_real = 7.0
theta_1_real = 9.0
y = theta_0_real + theta_1_real * X[:, 1]

# %%
# Testando com derivada autograd. Sua função deve retornar algo perto de 7 e 9
theta = gd(derivada_torch, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =  tensor([0.3629429638, 1.0165458918], requires_grad=True)
# Iter 1; theta =  tensor([0.4941345155, 1.1731483936])
# Iter 2; theta =  tensor([0.6227325201, 1.3266792297])
# Iter 3; theta =  tensor([0.7487885356, 1.4771986008])
# Iter 4; theta =  tensor([0.8723525405, 1.6247655153])
# Iter 5; theta =  tensor([0.9934739470, 1.7694380283])
# Iter 6; theta =  tensor([1.1122008562, 1.9112727642])
# Iter 7; theta =  tensor([1.2285808325, 2.0503253937])
# Iter 8; theta =  tensor([1.3426601887, 2.1866507530])
# Iter 9; theta =  tensor([1.4544844627, 2.3203020096])
# Iter 10; theta =  tensor([1.5640981197, 2.4513318539])
# Iter 11; theta =  tensor([1.6715449095, 2.5797915459])
# Iter 12; theta =  tensor([1.7768677473, 2.7057313919])
# Iter 13; theta =  tensor([1.8801084757, 2.8292007446])
# Iter 14; theta =  tensor([1.9813084602, 2.9502484798])
# Iter 15; theta =  tensor([2.0805079937, 3.0689218044])
# Iter 16; theta =  tensor([2.1777465343, 3.1852674484])
# Iter 17; theta =  tensor([2.2730629444, 3.2993309498])
# Iter 18; theta =  tensor([2.3664951324, 3.4111571312])
# Iter 19; theta =  tensor([2.4580802917, 3.5207896233])
# Iter 20; theta =  tensor([2.5478551388, 3.6282718182])
# Iter 21; theta =  tensor([2.6358554363, 3.7336456776])
# Iter 22; theta =  tensor([2.7221159935, 3.8369526863])
# Iter 23; theta =  tensor([2.8066713810, 3.9382331371])
# Iter 24; theta =  tensor([2.8895554543, 4.0375270844])
# Iter 25; theta =  tensor([2.9708011150, 4.1348733902])
# Iter 26; theta =  tensor([3.0504407883, 4.2303099632])
# Iter 27; theta =  tensor([3.1285061836, 4.3238749504])
# Iter 28; theta =  tensor([3.2050282955, 4.4156045914])
# Iter 29; theta =  tensor([3.2800378799, 4.5055346489])
# Iter 30; theta =  tensor([3.3535647392, 4.5937008858])
# Iter 31; theta =  tensor([3.4256381989, 4.6801376343])
# Iter 32; theta =  tensor([3.4962868690, 4.7648787498])
# Iter 33; theta =  tensor([3.5655391216, 4.8479576111])
# Iter 34; theta =  tensor([3.6334223747, 4.9294071198])
# Iter 35; theta =  tensor([3.6999638081, 5.0092587471])
# Iter 36; theta =  tensor([3.7651898861, 5.0875439644])
# Iter 37; theta =  tensor([3.8291265965, 5.1642937660])
# Iter 38; theta =  tensor([3.8917994499, 5.2395381927])
# Iter 39; theta =  tensor([3.9532334805, 5.3133063316])
# Iter 40; theta =  tensor([4.0134530067, 5.3856277466])
# Iter 41; theta =  tensor([4.0724821091, 5.4565305710])
# Iter 42; theta =  tensor([4.1303443909, 5.5260424614])
# Iter 43; theta =  tensor([4.1870632172, 5.5941905975])
# Iter 44; theta =  tensor([4.2426609993, 5.6610021591])
# Iter 45; theta =  tensor([4.2971596718, 5.7265033722])
# Iter 46; theta =  tensor([4.3505811691, 5.7907195091])
# Iter 47; theta =  tensor([4.4029464722, 5.8536758423])
# Iter 48; theta =  tensor([4.4542765617, 5.9153971672])
# Iter 49; theta =  tensor([4.5045924187, 5.9759078026])
# Iter 50; theta =  tensor([4.5539135933, 6.0352315903])
# Iter 51; theta =  tensor([4.6022596359, 6.0933918953])
# Iter 52; theta =  tensor([4.6496500969, 6.1504111290])
# Iter 53; theta =  tensor([4.6961040497, 6.2063117027])
# Iter 54; theta =  tensor([4.7416396141, 6.2611160278])
# Iter 55; theta =  tensor([4.7862753868, 6.3148450851])
# Iter 56; theta =  tensor([4.8300285339, 6.3675203323])
# Iter 57; theta =  tensor([4.8729171753, 6.4191622734])
# Iter 58; theta =  tensor([4.9149580002, 6.4697914124])
# Iter 59; theta =  tensor([4.9561676979, 6.5194272995])
# Iter 60; theta =  tensor([4.9965629578, 6.5680894852])
# Iter 61; theta =  tensor([5.0361595154, 6.6157970428])
# Iter 62; theta =  tensor([5.0749735832, 6.6625690460])
# Iter 63; theta =  tensor([5.1130204201, 6.7084236145])
# Iter 64; theta =  tensor([5.1503152847, 6.7533783913])
# Iter 65; theta =  tensor([5.1868729591, 6.7974514961])
# Iter 66; theta =  tensor([5.2227077484, 6.8406600952])
# Iter 67; theta =  tensor([5.2578344345, 6.8830208778])
# Iter 68; theta =  tensor([5.2922668457, 6.9245505333])
# Iter 69; theta =  tensor([5.3260188103, 6.9652657509])
# Iter 70; theta =  tensor([5.3591036797, 7.0051822662])
# Iter 71; theta =  tensor([5.3915343285, 7.0443158150])
# Iter 72; theta =  tensor([5.4233241081, 7.0826816559])
# Iter 73; theta =  tensor([5.4544854164, 7.1202950478])
# Iter 74; theta =  tensor([5.4850306511, 7.1571702957])
# Iter 75; theta =  tensor([5.5149722099, 7.1933221817])
# Iter 76; theta =  tensor([5.5443220139, 7.2287650108])
# Iter 77; theta =  tensor([5.5730919838, 7.2635126114])
# Iter 78; theta =  tensor([5.6012930870, 7.2975788116])
# Iter 79; theta =  tensor([5.6289367676, 7.3309764862])
# Iter 80; theta =  tensor([5.6560339928, 7.3637189865])
# Iter 81; theta =  tensor([5.6825957298, 7.3958191872])
# Iter 82; theta =  tensor([5.7086324692, 7.4272899628])
# Iter 83; theta =  tensor([5.7341547012, 7.4581432343])
# Iter 84; theta =  tensor([5.7591724396, 7.4883913994])
# Iter 85; theta =  tensor([5.7836956978, 7.5180459023])
# Iter 86; theta =  tensor([5.8077340126, 7.5471186638])
# Iter 87; theta =  tensor([5.8312973976, 7.5756211281])
# Iter 88; theta =  tensor([5.8543949127, 7.6035647392])
# Iter 89; theta =  tensor([5.8770360947, 7.6309599876])
# Iter 90; theta =  tensor([5.8992295265, 7.6578178406])
# Iter 91; theta =  tensor([5.9209842682, 7.6841487885])
# Iter 92; theta =  tensor([5.9423093796, 7.7099633217])
# Iter 93; theta =  tensor([5.9632129669, 7.7352714539])
# Iter 94; theta =  tensor([5.9837031364, 7.7600831985])
# Iter 95; theta =  tensor([6.0037884712, 7.7844080925])
# Iter 96; theta =  tensor([6.0234766006, 7.8082556725])
# Iter 97; theta =  tensor([6.0427756310, 7.8316354752])
# Iter 98; theta =  tensor([6.0616931915, 7.8545565605])
# Iter 99; theta =  tensor([6.0802369118, 7.8770279884])
# Iter 100; theta =  tensor([6.0984144211, 7.8990588188])
# Iter 101; theta =  tensor([6.1162323952, 7.9206576347])
# Iter 102; theta =  tensor([6.1336984634, 7.9418325424])
# Iter 103; theta =  tensor([6.1508193016, 7.9625921249])
# Iter 104; theta =  tensor([6.1676015854, 7.9829444885])
# Iter 105; theta =  tensor([6.1840519905, 8.0028972626])
# Iter 106; theta =  tensor([6.2001771927, 8.0224590302])
# Iter 107; theta =  tensor([6.2159838676, 8.0416364670])
# Iter 108; theta =  tensor([6.2314782143, 8.0604381561])
# Iter 109; theta =  tensor([6.2466664314, 8.0788707733])
# Iter 110; theta =  tensor([6.2615542412, 8.0969419479])
# Iter 111; theta =  tensor([6.2761478424, 8.1146583557])
# Iter 112; theta =  tensor([6.2904529572, 8.1320276260])
# Iter 113; theta =  tensor([6.3044753075, 8.1490564346])
# Iter 114; theta =  tensor([6.3182206154, 8.1657505035])
# Iter 115; theta =  tensor([6.3316941261, 8.1821174622])
# Iter 116; theta =  tensor([6.3449015617, 8.1981630325])
# Iter 117; theta =  tensor([6.3578476906, 8.2138938904])
# Iter 118; theta =  tensor([6.3705382347, 8.2293167114])
# Iter 119; theta =  tensor([6.3829779625, 8.2444362640])
# Iter 120; theta =  tensor([6.3951716423, 8.2592592239])
# Iter 121; theta =  tensor([6.4071245193, 8.2737913132])
# Iter 122; theta =  tensor([6.4188408852, 8.2880382538])
# Iter 123; theta =  tensor([6.4303259850, 8.3020057678])
# Iter 124; theta =  tensor([6.4415841103, 8.3156995773])
# Iter 125; theta =  tensor([6.4526195526, 8.3291244507])
# Iter 126; theta =  tensor([6.4634370804, 8.3422861099])
# Iter 127; theta =  tensor([6.4740405083, 8.3551893234])
# Iter 128; theta =  tensor([6.4844346046, 8.3678398132])
# Iter 129; theta =  tensor([6.4946231842, 8.3802423477])
# Iter 130; theta =  tensor([6.5046105385, 8.3924016953])
# Iter 131; theta =  tensor([6.5144004822, 8.4043226242])
# Iter 132; theta =  tensor([6.5239968300, 8.4160089493])
# Iter 133; theta =  tensor([6.5334033966, 8.4274663925])
# Iter 134; theta =  tensor([6.5426239967, 8.4386987686])
# Iter 135; theta =  tensor([6.5516624451, 8.4497108459])
# Iter 136; theta =  tensor([6.5605225563, 8.4605073929])
# Iter 137; theta =  tensor([6.5692071915, 8.4710922241])
# Iter 138; theta =  tensor([6.5777201653, 8.4814691544])
# Iter 139; theta =  tensor([6.5860652924, 8.4916419983])
# Iter 140; theta =  tensor([6.5942454338, 8.5016155243])
# Iter 141; theta =  tensor([6.6022639275, 8.5113935471])
# Iter 142; theta =  tensor([6.6101236343, 8.5209798813])
# Iter 143; theta =  tensor([6.6178283691, 8.5303783417])
# Iter 144; theta =  tensor([6.6253805161, 8.5395917892])
# Iter 145; theta =  tensor([6.6327834129, 8.5486249924])
# Iter 146; theta =  tensor([6.6400399208, 8.5574808121])
# Iter 147; theta =  tensor([6.6471533775, 8.5661630630])
# Iter 148; theta =  tensor([6.6541261673, 8.5746746063])
# Iter 149; theta =  tensor([6.6609611511, 8.5830192566])
# Iter 150; theta =  tensor([6.6676611900, 8.5911998749])
# Iter 151; theta =  tensor([6.6742286682, 8.5992202759])
# Iter 152; theta =  tensor([6.6806664467, 8.6070833206])
# Iter 153; theta =  tensor([6.6869769096, 8.6147918701])
# Iter 154; theta =  tensor([6.6931624413, 8.6223497391])
# Iter 155; theta =  tensor([6.6992259026, 8.6297588348])
# Iter 156; theta =  tensor([6.7051696777, 8.6370229721])
# Iter 157; theta =  tensor([6.7109956741, 8.6441440582])
# Iter 158; theta =  tensor([6.7167067528, 8.6511259079])
# Iter 159; theta =  tensor([6.7223048210, 8.6579704285])
# Iter 160; theta =  tensor([6.7277922630, 8.6646804810])
# Iter 161; theta =  tensor([6.7331714630, 8.6712589264])
# Iter 162; theta =  tensor([6.7384443283, 8.6777086258])
# Iter 163; theta =  tensor([6.7436127663, 8.6840314865])
# Iter 164; theta =  tensor([6.7486791611, 8.6902303696])
# Iter 165; theta =  tensor([6.7536454201, 8.6963081360])
# Iter 166; theta =  tensor([6.7585134506, 8.7022666931])
# Iter 167; theta =  tensor([6.7632851601, 8.7081079483])
# Iter 168; theta =  tensor([6.7679629326, 8.7138347626])
# Iter 169; theta =  tensor([6.7725481987, 8.7194490433])
# Iter 170; theta =  tensor([6.7770428658, 8.7249536514])
# Iter 171; theta =  tensor([6.7814488411, 8.7303504944])
# Iter 172; theta =  tensor([6.7857675552, 8.7356405258])
# Iter 173; theta =  tensor([6.7900009155, 8.7408275604])
# Iter 174; theta =  tensor([6.7941508293, 8.7459125519])
# Iter 175; theta =  tensor([6.7982187271, 8.7508974075])
# Iter 176; theta =  tensor([6.8022060394, 8.7557849884])
# Iter 177; theta =  tensor([6.8061146736, 8.7605762482])
# Iter 178; theta =  tensor([6.8099460602, 8.7652740479])
# Iter 179; theta =  tensor([6.8137016296, 8.7698793411])
# Iter 180; theta =  tensor([6.8173828125, 8.7743940353])
# Iter 181; theta =  tensor([6.8209915161, 8.7788200378])
# Iter 182; theta =  tensor([6.8245286942, 8.7831592560])
# Iter 183; theta =  tensor([6.8279962540, 8.7874135971])
# Iter 184; theta =  tensor([6.8313951492, 8.7915849686])
# Iter 185; theta =  tensor([6.8347268105, 8.7956743240])
# Iter 186; theta =  tensor([6.8379926682, 8.7996835709])
# Iter 187; theta =  tensor([6.8411941528, 8.8036136627])
# Iter 188; theta =  tensor([6.8443322182, 8.8074665070])
# Iter 189; theta =  tensor([6.8474082947, 8.8112440109])
# Iter 190; theta =  tensor([6.8504233360, 8.8149471283])
# Iter 191; theta =  tensor([6.8533787727, 8.8185777664])
# Iter 192; theta =  tensor([6.8562760353, 8.8221368790])
# Iter 193; theta =  tensor([6.8591160774, 8.8256263733])
# Iter 194; theta =  tensor([6.8618998528, 8.8290472031])
# Iter 195; theta =  tensor([6.8646287918, 8.8324012756])
# Iter 196; theta =  tensor([6.8673038483, 8.8356895447])
# Iter 197; theta =  tensor([6.8699259758, 8.8389129639])
# Iter 198; theta =  tensor([6.8724961281, 8.8420734406])
# Iter 199; theta =  tensor([6.8750157356, 8.8451719284])
# Iter 200; theta =  tensor([6.8774852753, 8.8482093811])
# Iter 201; theta =  tensor([6.8799061775, 8.8511877060])
# Iter 202; theta =  tensor([6.8822793961, 8.8541078568])
# Iter 203; theta =  tensor([6.8846054077, 8.8569707870])
# Iter 204; theta =  tensor([6.8868856430, 8.8597774506])
# Iter 205; theta =  tensor([6.8891205788, 8.8625288010])
# Iter 206; theta =  tensor([6.8913116455, 8.8652257919])
# Iter 207; theta =  tensor([6.8934593201, 8.8678703308])
# Iter 208; theta =  tensor([6.8955645561, 8.8704624176])
# Iter 209; theta =  tensor([6.8976283073, 8.8730039597])
# Iter 210; theta =  tensor([6.8996510506, 8.8754959106])
# Iter 211; theta =  tensor([6.9016337395, 8.8779392242])
# Iter 212; theta =  tensor([6.9035773277, 8.8803339005])
# Iter 213; theta =  tensor([6.9054827690, 8.8826818466])
# Iter 214; theta =  tensor([6.9073505402, 8.8849840164])
# Iter 215; theta =  tensor([6.9091811180, 8.8872404099])
# Iter 216; theta =  tensor([6.9109754562, 8.8894529343])
# Iter 217; theta =  tensor([6.9127345085, 8.8916215897])
# Iter 218; theta =  tensor([6.9144587517, 8.8937482834])
# Iter 219; theta =  tensor([6.9161491394, 8.8958330154])
# Iter 220; theta =  tensor([6.9178061485, 8.8978767395])
# Iter 221; theta =  tensor([6.9194302559, 8.8998804092])
# Iter 222; theta =  tensor([6.9210224152, 8.9018449783])
# Iter 223; theta =  tensor([6.9225831032, 8.9037704468])
# Iter 224; theta =  tensor([6.9241127968, 8.9056587219])
# Iter 225; theta =  tensor([6.9256124496, 8.9075098038])
# Iter 226; theta =  tensor([6.9270820618, 8.9093246460])
# Iter 227; theta =  tensor([6.9285225868, 8.9111042023])
# Iter 228; theta =  tensor([6.9299349785, 8.9128484726])
# Iter 229; theta =  tensor([6.9313192368, 8.9145584106])
# Iter 230; theta =  tensor([6.9326763153, 8.9162349701])
# Iter 231; theta =  tensor([6.9340066910, 8.9178781509])
# Iter 232; theta =  tensor([6.9353108406, 8.9194898605])
# Iter 233; theta =  tensor([6.9365887642, 8.9210691452])
# Iter 234; theta =  tensor([6.9378418922, 8.9226179123])
# Iter 235; theta =  tensor([6.9390702248, 8.9241361618])
# Iter 236; theta =  tensor([6.9402742386, 8.9256248474])
# Iter 237; theta =  tensor([6.9414544106, 8.9270839691])
# Iter 238; theta =  tensor([6.9426112175, 8.9285144806])
# Iter 239; theta =  tensor([6.9437451363, 8.9299173355])
# Iter 240; theta =  tensor([6.9448566437, 8.9312925339])
# Iter 241; theta =  tensor([6.9459462166, 8.9326410294])
# Iter 242; theta =  tensor([6.9470143318, 8.9339628220])
# Iter 243; theta =  tensor([6.9480609894, 8.9352588654])
# Iter 244; theta =  tensor([6.9490871429, 8.9365291595])
# Iter 245; theta =  tensor([6.9500932693, 8.9377746582])
# Iter 246; theta =  tensor([6.9510793686, 8.9389953613])
# Iter 247; theta =  tensor([6.9520459175, 8.9401922226])
# Iter 248; theta =  tensor([6.9529933929, 8.9413661957])
# Iter 249; theta =  tensor([6.9539222717, 8.9425163269])
# Iter 250; theta =  tensor([6.9548325539, 8.9436445236])
# Iter 251; theta =  tensor([6.9557251930, 8.9447507858])
# Iter 252; theta =  tensor([6.9566001892, 8.9458351135])
# Iter 253; theta =  tensor([6.9574575424, 8.9468975067])
# Iter 254; theta =  tensor([6.9582982063, 8.9479398727])
# Iter 255; theta =  tensor([6.9591221809, 8.9489612579])
# Iter 256; theta =  tensor([6.9599299431, 8.9499626160])
# Iter 257; theta =  tensor([6.9607214928, 8.9509449005])
# Iter 258; theta =  tensor([6.9614973068, 8.9519071579])
# Iter 259; theta =  tensor([6.9622578621, 8.9528512955])
# Iter 260; theta =  tensor([6.9630036354, 8.9537763596])
# Iter 261; theta =  tensor([6.9637346268, 8.9546833038])
# Iter 262; theta =  tensor([6.9644513130, 8.9555721283])
# Iter 263; theta =  tensor([6.9651536942, 8.9564437866])
# Iter 264; theta =  tensor([6.9658422470, 8.9572982788])
# Iter 265; theta =  tensor([6.9665169716, 8.9581365585])
# Iter 266; theta =  tensor([6.9671783447, 8.9589576721])
# Iter 267; theta =  tensor([6.9678268433, 8.9597625732])
# Iter 268; theta =  tensor([6.9684624672, 8.9605522156])
# Iter 269; theta =  tensor([6.9690856934, 8.9613265991])
# Iter 270; theta =  tensor([6.9696965218, 8.9620857239])
# Iter 271; theta =  tensor([6.9702954292, 8.9628295898])
# Iter 272; theta =  tensor([6.9708824158, 8.9635591507])
# Iter 273; theta =  tensor([6.9714574814, 8.9642744064])
# Iter 274; theta =  tensor([6.9720215797, 8.9649753571])
# Iter 275; theta =  tensor([6.9725742340, 8.9656629562])
# Iter 276; theta =  tensor([6.9731159210, 8.9663362503])
# Iter 277; theta =  tensor([6.9736471176, 8.9669971466])
# Iter 278; theta =  tensor([6.9741678238, 8.9676446915])
# Iter 279; theta =  tensor([6.9746780396, 8.9682798386])
# Iter 280; theta =  tensor([6.9751782417, 8.9689025879])
# Iter 281; theta =  tensor([6.9756684303, 8.9695129395])
# Iter 282; theta =  tensor([6.9761490822, 8.9701108932])
# Iter 283; theta =  tensor([6.9766201973, 8.9706974030])
# Iter 284; theta =  tensor([6.9770822525, 8.9712724686])
# Iter 285; theta =  tensor([6.9775352478, 8.9718360901])
# Iter 286; theta =  tensor([6.9779791832, 8.9723882675])
# Iter 287; theta =  tensor([6.9784140587, 8.9729299545])
# Iter 288; theta =  tensor([6.9788403511, 8.9734611511])
# Iter 289; theta =  tensor([6.9792585373, 8.9739818573])
# Iter 290; theta =  tensor([6.9796681404, 8.9744920731])
# Iter 291; theta =  tensor([6.9800696373, 8.9749927521])
# Iter 292; theta =  tensor([6.9804635048, 8.9754838943])
# Iter 293; theta =  tensor([6.9808492661, 8.9759645462])
# Iter 294; theta =  tensor([6.9812273979, 8.9764366150])
# Iter 295; theta =  tensor([6.9815983772, 8.9768991470])
# Iter 296; theta =  tensor([6.9819617271, 8.9773521423])
# Iter 297; theta =  tensor([6.9823179245, 8.9777965546])
# Iter 298; theta =  tensor([6.9826674461, 8.9782323837])
# Iter 299; theta =  tensor([6.9830098152, 8.9786596298])
# Iter 300; theta =  tensor([6.9833455086, 8.9790782928])
# Iter 301; theta =  tensor([6.9836745262, 8.9794883728])
# Iter 302; theta =  tensor([6.9839968681, 8.9798908234])
# Iter 303; theta =  tensor([6.9843130112, 8.9802856445])
# Iter 304; theta =  tensor([6.9846229553, 8.9806728363])
# Iter 305; theta =  tensor([6.9849267006, 8.9810523987])
# Iter 306; theta =  tensor([6.9852247238, 8.9814243317])
# Iter 307; theta =  tensor([6.9855165482, 8.9817886353])
# Iter 308; theta =  tensor([6.9858026505, 8.9821462631])
# Iter 309; theta =  tensor([6.9860830307, 8.9824962616])
# Iter 310; theta =  tensor([6.9863581657, 8.9828395844])
# Iter 311; theta =  tensor([6.9866275787, 8.9831762314])
# Iter 312; theta =  tensor([6.9868917465, 8.9835062027])
# Iter 313; theta =  tensor([6.9871506691, 8.9838294983])
# Iter 314; theta =  tensor([6.9874043465, 8.9841470718])
# Iter 315; theta =  tensor([6.9876532555, 8.9844579697])
# Iter 316; theta =  tensor([6.9878973961, 8.9847631454])
# Iter 317; theta =  tensor([6.9881362915, 8.9850625992])
# Iter 318; theta =  tensor([6.9883708954, 8.9853553772])
# Iter 319; theta =  tensor([6.9886007309, 8.9856424332])
# Iter 320; theta =  tensor([6.9888257980, 8.9859237671])
# Iter 321; theta =  tensor([6.9890465736, 8.9862003326])
# Iter 322; theta =  tensor([6.9892630577, 8.9864711761])
# Iter 323; theta =  tensor([6.9894752502, 8.9867362976])
# Iter 324; theta =  tensor([6.9896831512, 8.9869966507])
# Iter 325; theta =  tensor([6.9898867607, 8.9872522354])
# Iter 326; theta =  tensor([6.9900865555, 8.9875020981])
# Iter 327; theta =  tensor([6.9902825356, 8.9877471924])

# %%
theta
# Out:
# tensor([6.9902825356, 8.9877471924], requires_grad=True)

# %%
# Testando com derivada manual. Sua função deve retornar algo perto de 7 e 9
theta = gd(derivada_navera, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =  tensor([0.1850057989, 2.2072958946], requires_grad=True)
# Iter 1; theta =  tensor([0.2524964809, 2.2738049030])
# Iter 2; theta =  tensor([0.3193187118, 2.3396627903])
# Iter 3; theta =  tensor([0.3854791224, 2.4048759937])
# Iter 4; theta =  tensor([0.4509842396, 2.4694507122])
# Iter 5; theta =  tensor([0.5158405900, 2.5333931446])
# Iter 6; theta =  tensor([0.5800545812, 2.5967097282])
# Iter 7; theta =  tensor([0.6436325908, 2.6594064236])
# Iter 8; theta =  tensor([0.7065808773, 2.7214891911])
# Iter 9; theta =  tensor([0.7689056993, 2.7829642296])
# Iter 10; theta =  tensor([0.8306131959, 2.8438374996])
# Iter 11; theta =  tensor([0.8917095661, 2.9041147232])
# Iter 12; theta =  tensor([0.9522007704, 2.9638018608])
# Iter 13; theta =  tensor([1.0120928288, 3.0229046345])
# Iter 14; theta =  tensor([1.0713918209, 3.0814287663])
# Iter 15; theta =  tensor([1.1301034689, 3.1393799782])
# Iter 16; theta =  tensor([1.1882334948, 3.1967637539])
# Iter 17; theta =  tensor([1.2457879782, 3.2535858154])
# Iter 18; theta =  tensor([1.3027724028, 3.3098514080])
# Iter 19; theta =  tensor([1.3591923714, 3.3655662537])
# Iter 20; theta =  tensor([1.4150536060, 3.4207355976])
# Iter 21; theta =  tensor([1.4703615904, 3.4753649235])
# Iter 22; theta =  tensor([1.5251218081, 3.5294592381])
# Iter 23; theta =  tensor([1.5793396235, 3.5830240250])
# Iter 24; theta =  tensor([1.6330204010, 3.6360642910])
# Iter 25; theta =  tensor([1.6861696243, 3.6885852814])
# Iter 26; theta =  tensor([1.7387924194, 3.7405920029])
# Iter 27; theta =  tensor([1.7908940315, 3.7920897007])
# Iter 28; theta =  tensor([1.8424795866, 3.8430831432])
# Iter 29; theta =  tensor([1.8935542107, 3.8935773373])
# Iter 30; theta =  tensor([1.9441230297, 3.9435772896])
# Iter 31; theta =  tensor([1.9941910505, 3.9930877686])
# Iter 32; theta =  tensor([2.0437631607, 4.0421133041])
# Iter 33; theta =  tensor([2.0928442478, 4.0906591415])
# Iter 34; theta =  tensor([2.1414394379, 4.1387295723])
# Iter 35; theta =  tensor([2.1895532608, 4.1863293648])
# Iter 36; theta =  tensor([2.2371904850, 4.2334632874])
# Iter 37; theta =  tensor([2.2843558788, 4.2801356316])
# Iter 38; theta =  tensor([2.3310542107, 4.3263511658])
# Iter 39; theta =  tensor([2.3772900105, 4.3721141815])
# Iter 40; theta =  tensor([2.4230680466, 4.4174289703])
# Iter 41; theta =  tensor([2.4683926105, 4.4623003006])
# Iter 42; theta =  tensor([2.5132682323, 4.5067319870])
# Iter 43; theta =  tensor([2.5576994419, 4.5507287979])
# Iter 44; theta =  tensor([2.6016905308, 4.5942950249])
# Iter 45; theta =  tensor([2.6452460289, 4.6374344826])
# Iter 46; theta =  tensor([2.6883702278, 4.6801514626])
# Iter 47; theta =  tensor([2.7310671806, 4.7224502563])
# Iter 48; theta =  tensor([2.7733414173, 4.7643351555])
# Iter 49; theta =  tensor([2.8151969910, 4.8058099747])
# Iter 50; theta =  tensor([2.8566379547, 4.8468785286])
# Iter 51; theta =  tensor([2.8976683617, 4.8875451088])
# Iter 52; theta =  tensor([2.9382925034, 4.9278135300])
# Iter 53; theta =  tensor([2.9785144329, 4.9676876068])
# Iter 54; theta =  tensor([3.0183379650, 5.0071711540])
# Iter 55; theta =  tensor([3.0577671528, 5.0462684631])
# Iter 56; theta =  tensor([3.0968058109, 5.0849828720])
# Iter 57; theta =  tensor([3.1354577541, 5.1233181953])
# Iter 58; theta =  tensor([3.1737270355, 5.1612782478])
# Iter 59; theta =  tensor([3.2116172314, 5.1988663673])
# Iter 60; theta =  tensor([3.2491321564, 5.2360868454])
# Iter 61; theta =  tensor([3.2862753868, 5.2729425430])
# Iter 62; theta =  tensor([3.3230509758, 5.3094377518])
# Iter 63; theta =  tensor([3.3594622612, 5.3455753326])
# Iter 64; theta =  tensor([3.3955130577, 5.3813591003])
# Iter 65; theta =  tensor([3.4312067032, 5.4167928696])
# Iter 66; theta =  tensor([3.4665467739, 5.4518795013])
# Iter 67; theta =  tensor([3.5015368462, 5.4866228104])
# Iter 68; theta =  tensor([3.5361804962, 5.5210256577])
# Iter 69; theta =  tensor([3.5704810619, 5.5550918579])
# Iter 70; theta =  tensor([3.6044418812, 5.5888242722])
# Iter 71; theta =  tensor([3.6380662918, 5.6222267151])
# Iter 72; theta =  tensor([3.6713578701, 5.6553020477])
# Iter 73; theta =  tensor([3.7043197155, 5.6880536079])
# Iter 74; theta =  tensor([3.7369551659, 5.7204842567])
# Iter 75; theta =  tensor([3.7692673206, 5.7525973320])
# Iter 76; theta =  tensor([3.8012595177, 5.7843961716])
# Iter 77; theta =  tensor([3.8329348564, 5.8158836365])
# Iter 78; theta =  tensor([3.8642964363, 5.8470625877])
# Iter 79; theta =  tensor([3.8953473568, 5.8779363632])
# Iter 80; theta =  tensor([3.9260909557, 5.9085078239])
# Iter 81; theta =  tensor([3.9565300941, 5.9387803078])
# Iter 82; theta =  tensor([3.9866676331, 5.9687561989])
# Iter 83; theta =  tensor([4.0165066719, 5.9984383583])
# Iter 84; theta =  tensor([4.0460500717, 6.0278301239])
# Iter 85; theta =  tensor([4.0753011703, 6.0569343567])
# Iter 86; theta =  tensor([4.1042623520, 6.0857534409])
# Iter 87; theta =  tensor([4.1329369545, 6.1142902374])
# Iter 88; theta =  tensor([4.1613273621, 6.1425476074])
# Iter 89; theta =  tensor([4.1894369125, 6.1705284119])
# Iter 90; theta =  tensor([4.2172679901, 6.1982350349])
# Iter 91; theta =  tensor([4.2448234558, 6.2256703377])
# Iter 92; theta =  tensor([4.2721061707, 6.2528371811])
# Iter 93; theta =  tensor([4.2991185188, 6.2797379494])
# Iter 94; theta =  tensor([4.3258633614, 6.3063755035])
# Iter 95; theta =  tensor([4.3523430824, 6.3327522278])
# Iter 96; theta =  tensor([4.3785605431, 6.3588705063])
# Iter 97; theta =  tensor([4.4045186043, 6.3847332001])
# Iter 98; theta =  tensor([4.4302196503, 6.4103426933])
# Iter 99; theta =  tensor([4.4556660652, 6.4357013702])
# Iter 100; theta =  tensor([4.4808607101, 6.4608116150])
# Iter 101; theta =  tensor([4.5058054924, 6.4856762886])
# Iter 102; theta =  tensor([4.5305032730, 6.5102972984])
# Iter 103; theta =  tensor([4.5549564362, 6.5346775055])
# Iter 104; theta =  tensor([4.5791673660, 6.5588188171])
# Iter 105; theta =  tensor([4.6031389236, 6.5827236176])
# Iter 106; theta =  tensor([4.6268730164, 6.6063947678])
# Iter 107; theta =  tensor([4.6503720284, 6.6298336983])
# Iter 108; theta =  tensor([4.6736383438, 6.6530432701])
# Iter 109; theta =  tensor([4.6966743469, 6.6760258675])
# Iter 110; theta =  tensor([4.7194819450, 6.6987833977])
# Iter 111; theta =  tensor([4.7420639992, 6.7213177681])
# Iter 112; theta =  tensor([4.7644224167, 6.7436318398])
# Iter 113; theta =  tensor([4.7865591049, 6.7657270432])
# Iter 114; theta =  tensor([4.8084764481, 6.7876062393])
# Iter 115; theta =  tensor([4.8301768303, 6.8092708588])
# Iter 116; theta =  tensor([4.8516626358, 6.8307237625])
# Iter 117; theta =  tensor([4.8729352951, 6.8519663811])
# Iter 118; theta =  tensor([4.8939976692, 6.8730010986])
# Iter 119; theta =  tensor([4.9148511887, 6.8938298225])
# Iter 120; theta =  tensor([4.9354982376, 6.9144544601])
# Iter 121; theta =  tensor([4.9559407234, 6.9348773956])
# Iter 122; theta =  tensor([4.9761810303, 6.9551000595])
# Iter 123; theta =  tensor([4.9962205887, 6.9751248360])
# Iter 124; theta =  tensor([5.0160617828, 6.9949536324])
# Iter 125; theta =  tensor([5.0357065201, 7.0145883560])
# Iter 126; theta =  tensor([5.0551567078, 7.0340309143])
# Iter 127; theta =  tensor([5.0744142532, 7.0532827377])
# Iter 128; theta =  tensor([5.0934810638, 7.0723462105])
# Iter 129; theta =  tensor([5.1123590469, 7.0912232399])
# Iter 130; theta =  tensor([5.1310501099, 7.1099152565])
# Iter 131; theta =  tensor([5.1495561600, 7.1284241676])
# Iter 132; theta =  tensor([5.1678791046, 7.1467518806])
# Iter 133; theta =  tensor([5.1860203743, 7.1649003029])
# Iter 134; theta =  tensor([5.2039818764, 7.1828708649])
# Iter 135; theta =  tensor([5.2217655182, 7.2006654739])
# Iter 136; theta =  tensor([5.2393732071, 7.2182860374])
# Iter 137; theta =  tensor([5.2568063736, 7.2357339859])
# Iter 138; theta =  tensor([5.2740669250, 7.2530107498])
# Iter 139; theta =  tensor([5.2911567688, 7.2701187134])
# Iter 140; theta =  tensor([5.3080773354, 7.2870588303])
# Iter 141; theta =  tensor([5.3248305321, 7.3038334846])
# Iter 142; theta =  tensor([5.3414177895, 7.3204436302])
# Iter 143; theta =  tensor([5.3578405380, 7.3368911743])
# Iter 144; theta =  tensor([5.3741006851, 7.3531775475])
# Iter 145; theta =  tensor([5.3901996613, 7.3693046570])
# Iter 146; theta =  tensor([5.4061393738, 7.3852739334])
# Iter 147; theta =  tensor([5.4219212532, 7.4010868073])
# Iter 148; theta =  tensor([5.4375467300, 7.4167447090])
# Iter 149; theta =  tensor([5.4530177116, 7.4322490692])
# Iter 150; theta =  tensor([5.4683351517, 7.4476017952])
# Iter 151; theta =  tensor([5.4835009575, 7.4628043175])
# Iter 152; theta =  tensor([5.4985165596, 7.4778580666])
# Iter 153; theta =  tensor([5.5133838654, 7.4927639961])
# Iter 154; theta =  tensor([5.5281038284, 7.5075240135])
# Iter 155; theta =  tensor([5.5426778793, 7.5221395493])
# Iter 156; theta =  tensor([5.5571074486, 7.5366120338])
# Iter 157; theta =  tensor([5.5713944435, 7.5509428978])
# Iter 158; theta =  tensor([5.5855398178, 7.5651335716])
# Iter 159; theta =  tensor([5.5995450020, 7.5791850090])
# Iter 160; theta =  tensor([5.6134114265, 7.5930991173])
# Iter 161; theta =  tensor([5.6271409988, 7.6068768501])
# Iter 162; theta =  tensor([5.6407341957, 7.6205196381])
# Iter 163; theta =  tensor([5.6541929245, 7.6340289116])
# Iter 164; theta =  tensor([5.6675186157, 7.6474061012])
# Iter 165; theta =  tensor([5.6807122231, 7.6606521606])
# Iter 166; theta =  tensor([5.6937751770, 7.6737685204])
# Iter 167; theta =  tensor([5.7067089081, 7.6867561340])
# Iter 168; theta =  tensor([5.7195143700, 7.6996169090])
# Iter 169; theta =  tensor([5.7321929932, 7.7123517990])
# Iter 170; theta =  tensor([5.7447462082, 7.7249617577])
# Iter 171; theta =  tensor([5.7571749687, 7.7374482155])
# Iter 172; theta =  tensor([5.7694807053, 7.7498126030])
# Iter 173; theta =  tensor([5.7816643715, 7.7620558739])
# Iter 174; theta =  tensor([5.7937273979, 7.7741789818])
# Iter 175; theta =  tensor([5.8056712151, 7.7861833572])
# Iter 176; theta =  tensor([5.8174967766, 7.7980704308])
# Iter 177; theta =  tensor([5.8292050362, 7.8098411560])
# Iter 178; theta =  tensor([5.8407974243, 7.8214964867])
# Iter 179; theta =  tensor([5.8522748947, 7.8330378532])
# Iter 180; theta =  tensor([5.8636388779, 7.8444662094])
# Iter 181; theta =  tensor([5.8748903275, 7.8557825089])
# Iter 182; theta =  tensor([5.8860301971, 7.8669881821])
# Iter 183; theta =  tensor([5.8970599174, 7.8780841827])
# Iter 184; theta =  tensor([5.9079804420, 7.8890714645])
# Iter 185; theta =  tensor([5.9187927246, 7.8999509811])
# Iter 186; theta =  tensor([5.9294981956, 7.9107241631])
# Iter 187; theta =  tensor([5.9400973320, 7.9213914871])
# Iter 188; theta =  tensor([5.9505915642, 7.9319543839])
# Iter 189; theta =  tensor([5.9609818459, 7.9424138069])
# Iter 190; theta =  tensor([5.9712696075, 7.9527711868])
# Iter 191; theta =  tensor([5.9814553261, 7.9630270004])
# Iter 192; theta =  tensor([5.9915399551, 7.9731822014])
# Iter 193; theta =  tensor([6.0015249252, 7.9832382202])
# Iter 194; theta =  tensor([6.0114111900, 7.9931955338])
# Iter 195; theta =  tensor([6.0211992264, 8.0030555725])
# Iter 196; theta =  tensor([6.0308904648, 8.0128192902])
# Iter 197; theta =  tensor([6.0404858589, 8.0224866867])
# Iter 198; theta =  tensor([6.0499863625, 8.0320596695])
# Iter 199; theta =  tensor([6.0593924522, 8.0415391922])
# Iter 200; theta =  tensor([6.0687055588, 8.0509262085])
# Iter 201; theta =  tensor([6.0779261589, 8.0602207184])
# Iter 202; theta =  tensor([6.0870556831, 8.0694246292])
# Iter 203; theta =  tensor([6.0960946083, 8.0785379410])
# Iter 204; theta =  tensor([6.1050443649, 8.0875625610])
# Iter 205; theta =  tensor([6.1139054298, 8.0964984894])
# Iter 206; theta =  tensor([6.1226787567, 8.1053466797])
# Iter 207; theta =  tensor([6.1313652992, 8.1141080856])
# Iter 208; theta =  tensor([6.1399655342, 8.1227836609])
# Iter 209; theta =  tensor([6.1484808922, 8.1313743591])
# Iter 210; theta =  tensor([6.1569118500, 8.1398811340])
# Iter 211; theta =  tensor([6.1652593613, 8.1483049393])
# Iter 212; theta =  tensor([6.1735239029, 8.1566457748])
# Iter 213; theta =  tensor([6.1817069054, 8.1649055481])
# Iter 214; theta =  tensor([6.1898088455, 8.1730842590])
# Iter 215; theta =  tensor([6.1978306770, 8.1811828613])
# Iter 216; theta =  tensor([6.2057728767, 8.1892023087])
# Iter 217; theta =  tensor([6.2136363983, 8.1971426010])
# Iter 218; theta =  tensor([6.2214221954, 8.2050056458])
# Iter 219; theta =  tensor([6.2291307449, 8.2127914429])
# Iter 220; theta =  tensor([6.2367630005, 8.2205009460])
# Iter 221; theta =  tensor([6.2443199158, 8.2281351089])
# Iter 222; theta =  tensor([6.2518019676, 8.2356948853])
# Iter 223; theta =  tensor([6.2592096329, 8.2431802750])
# Iter 224; theta =  tensor([6.2665438652, 8.2505922318])
# Iter 225; theta =  tensor([6.2738056183, 8.2579317093])
# Iter 226; theta =  tensor([6.2809953690, 8.2651996613])
# Iter 227; theta =  tensor([6.2881140709, 8.2723960876])
# Iter 228; theta =  tensor([6.2951622009, 8.2795219421])
# Iter 229; theta =  tensor([6.3021407127, 8.2865781784])
# Iter 230; theta =  tensor([6.3090500832, 8.2935647964])
# Iter 231; theta =  tensor([6.3158907890, 8.3004837036])
# Iter 232; theta =  tensor([6.3226637840, 8.3073348999])
# Iter 233; theta =  tensor([6.3293700218, 8.3141183853])
# Iter 234; theta =  tensor([6.3360099792, 8.3208360672])
# Iter 235; theta =  tensor([6.3425841331, 8.3274879456])
# Iter 236; theta =  tensor([6.3490929604, 8.3340740204])
# Iter 237; theta =  tensor([6.3555374146, 8.3405961990])
# Iter 238; theta =  tensor([6.3619179726, 8.3470544815])
# Iter 239; theta =  tensor([6.3682355881, 8.3534488678])
# Iter 240; theta =  tensor([6.3744902611, 8.3597812653])
# Iter 241; theta =  tensor([6.3806834221, 8.3660516739])
# Iter 242; theta =  tensor([6.3868150711, 8.3722600937])
# Iter 243; theta =  tensor([6.3928861618, 8.3784084320])
# Iter 244; theta =  tensor([6.3988971710, 8.3844957352])
# Iter 245; theta =  tensor([6.4048485756, 8.3905239105])
# Iter 246; theta =  tensor([6.4107408524, 8.3964929581])
# Iter 247; theta =  tensor([6.4165749550, 8.4024038315])
# Iter 248; theta =  tensor([6.4223513603, 8.4082565308])
# Iter 249; theta =  tensor([6.4280705452, 8.4140520096])
# Iter 250; theta =  tensor([6.4337329865, 8.4197902679])
# Iter 251; theta =  tensor([6.4393391609, 8.4254732132])
# Iter 252; theta =  tensor([6.4448900223, 8.4310998917])
# Iter 253; theta =  tensor([6.4503860474, 8.4366712570])
# Iter 254; theta =  tensor([6.4558277130, 8.4421882629])
# Iter 255; theta =  tensor([6.4612154961, 8.4476518631])
# Iter 256; theta =  tensor([6.4665498734, 8.4530611038])
# Iter 257; theta =  tensor([6.4718313217, 8.4584178925])
# Iter 258; theta =  tensor([6.4770603180, 8.4637222290])
# Iter 259; theta =  tensor([6.4822378159, 8.4689741135])
# Iter 260; theta =  tensor([6.4873638153, 8.4741754532])
# Iter 261; theta =  tensor([6.4924392700, 8.4793252945])
# Iter 262; theta =  tensor([6.4974641800, 8.4844245911])
# Iter 263; theta =  tensor([6.5024394989, 8.4894742966])
# Iter 264; theta =  tensor([6.5073657036, 8.4944744110])
# Iter 265; theta =  tensor([6.5122427940, 8.4994258881])
# Iter 266; theta =  tensor([6.5170717239, 8.5043287277])
# Iter 267; theta =  tensor([6.5218529701, 8.5091829300])
# Iter 268; theta =  tensor([6.5265870094, 8.5139904022])
# Iter 269; theta =  tensor([6.5312738419, 8.5187501907])
# Iter 270; theta =  tensor([6.5359144211, 8.5234632492])
# Iter 271; theta =  tensor([6.5405092239, 8.5281305313])
# Iter 272; theta =  tensor([6.5450582504, 8.5327520370])
# Iter 273; theta =  tensor([6.5495624542, 8.5373287201])
# Iter 274; theta =  tensor([6.5540218353, 8.5418605804])
# Iter 275; theta =  tensor([6.5584373474, 8.5463476181])
# Iter 276; theta =  tensor([6.5628089905, 8.5507907867])
# Iter 277; theta =  tensor([6.5671372414, 8.5551900864])
# Iter 278; theta =  tensor([6.5714225769, 8.5595464706])
# Iter 279; theta =  tensor([6.5756654739, 8.5638599396])
# Iter 280; theta =  tensor([6.5798664093, 8.5681314468])
# Iter 281; theta =  tensor([6.5840258598, 8.5723609924])
# Iter 282; theta =  tensor([6.5881443024, 8.5765495300])
# Iter 283; theta =  tensor([6.5922217369, 8.5806970596])
# Iter 284; theta =  tensor([6.5962586403, 8.5848035812])
# Iter 285; theta =  tensor([6.6002559662, 8.5888700485])
# Iter 286; theta =  tensor([6.6042137146, 8.5928964615])
# Iter 287; theta =  tensor([6.6081318855, 8.5968837738])
# Iter 288; theta =  tensor([6.6120114326, 8.6008319855])
# Iter 289; theta =  tensor([6.6158523560, 8.6047410965])
# Iter 290; theta =  tensor([6.6196556091, 8.6086120605])
# Iter 291; theta =  tensor([6.6234211922, 8.6124458313])
# Iter 292; theta =  tensor([6.6271495819, 8.6162414551])
# Iter 293; theta =  tensor([6.6308407784, 8.6199998856])
# Iter 294; theta =  tensor([6.6344952583, 8.6237220764])
# Iter 295; theta =  tensor([6.6381139755, 8.6274070740])
# Iter 296; theta =  tensor([6.6416964531, 8.6310567856])
# Iter 297; theta =  tensor([6.6452436447, 8.6346702576])
# Iter 298; theta =  tensor([6.6487555504, 8.6382484436])
# Iter 299; theta =  tensor([6.6522331238, 8.6417913437])
# Iter 300; theta =  tensor([6.6556758881, 8.6452999115])
# Iter 301; theta =  tensor([6.6590847969, 8.6487741470])
# Iter 302; theta =  tensor([6.6624598503, 8.6522140503])
# Iter 303; theta =  tensor([6.6658015251, 8.6556205750])
# Iter 304; theta =  tensor([6.6691102982, 8.6589937210])
# Iter 305; theta =  tensor([6.6723861694, 8.6623334885])
# Iter 306; theta =  tensor([6.6756296158, 8.6656408310])
# Iter 307; theta =  tensor([6.6788406372, 8.6689157486])
# Iter 308; theta =  tensor([6.6820201874, 8.6721582413])
# Iter 309; theta =  tensor([6.6851682663, 8.6753692627])
# Iter 310; theta =  tensor([6.6882848740, 8.6785488129])
# Iter 311; theta =  tensor([6.6913709641, 8.6816968918])
# Iter 312; theta =  tensor([6.6944265366, 8.6848144531])
# Iter 313; theta =  tensor([6.6974515915, 8.6879014969])
# Iter 314; theta =  tensor([6.7004466057, 8.6909580231])
# Iter 315; theta =  tensor([6.7034120560, 8.6939849854])
# Iter 316; theta =  tensor([6.7063484192, 8.6969823837])
# Iter 317; theta =  tensor([6.7092556953, 8.6999502182])
# Iter 318; theta =  tensor([6.7121338844, 8.7028894424])
# Iter 319; theta =  tensor([6.7149839401, 8.7057991028])
# Iter 320; theta =  tensor([6.7178053856, 8.7086811066])
# Iter 321; theta =  tensor([6.7205991745, 8.7115345001])
# Iter 322; theta =  tensor([6.7233653069, 8.7143602371])
# Iter 323; theta =  tensor([6.7261037827, 8.7171583176])
# Iter 324; theta =  tensor([6.7288150787, 8.7199287415])
# Iter 325; theta =  tensor([6.7314996719, 8.7226715088])
# Iter 326; theta =  tensor([6.7341575623, 8.7253875732])
# Iter 327; theta =  tensor([6.7367892265, 8.7280769348])
# Iter 328; theta =  tensor([6.7393951416, 8.7307405472])
# Iter 329; theta =  tensor([6.7419748306, 8.7333774567])
# Iter 330; theta =  tensor([6.7445292473, 8.7359886169])
# Iter 331; theta =  tensor([6.7470583916, 8.7385749817])
# Iter 332; theta =  tensor([6.7495622635, 8.7411355972])
# Iter 333; theta =  tensor([6.7520413399, 8.7436714172])
# Iter 334; theta =  tensor([6.7544960976, 8.7461824417])
# Iter 335; theta =  tensor([6.7569265366, 8.7486686707])
# Iter 336; theta =  tensor([6.7593326569, 8.7511301041])
# Iter 337; theta =  tensor([6.7617154121, 8.7535676956])
# Iter 338; theta =  tensor([6.7640743256, 8.7559814453])
# Iter 339; theta =  tensor([6.7664098740, 8.7583713531])
# Iter 340; theta =  tensor([6.7687225342, 8.7607383728])
# Iter 341; theta =  tensor([6.7710123062, 8.7630815506])
# Iter 342; theta =  tensor([6.7732791901, 8.7654018402])
# Iter 343; theta =  tensor([6.7755236626, 8.7676992416])
# Iter 344; theta =  tensor([6.7777457237, 8.7699747086])
# Iter 345; theta =  tensor([6.7799458504, 8.7722282410])
# Iter 346; theta =  tensor([6.7821245193, 8.7744588852])
# Iter 347; theta =  tensor([6.7842812538, 8.7766675949])
# Iter 348; theta =  tensor([6.7864165306, 8.7788553238])
# Iter 349; theta =  tensor([6.7885308266, 8.7810211182])
# Iter 350; theta =  tensor([6.7906241417, 8.7831659317])
# Iter 351; theta =  tensor([6.7926969528, 8.7852897644])
# Iter 352; theta =  tensor([6.7947492599, 8.7873926163])
# Iter 353; theta =  tensor([6.7967810631, 8.7894754410])
# Iter 354; theta =  tensor([6.7987928391, 8.7915372849])
# Iter 355; theta =  tensor([6.8007845879, 8.7935791016])
# Iter 356; theta =  tensor([6.8027567863, 8.7956008911])
# Iter 357; theta =  tensor([6.8047094345, 8.7976026535])
# Iter 358; theta =  tensor([6.8066425323, 8.7995853424])
# Iter 359; theta =  tensor([6.8085565567, 8.8015480042])
# Iter 360; theta =  tensor([6.8104515076, 8.8034915924])
# Iter 361; theta =  tensor([6.8123278618, 8.8054161072])
# Iter 362; theta =  tensor([6.8141856194, 8.8073225021])
# Iter 363; theta =  tensor([6.8160252571, 8.8092098236])
# Iter 364; theta =  tensor([6.8178462982, 8.8110790253])
# Iter 365; theta =  tensor([6.8196496964, 8.8129291534])
# Iter 366; theta =  tensor([6.8214349747, 8.8147611618])
# Iter 367; theta =  tensor([6.8232026100, 8.8165760040])
# Iter 368; theta =  tensor([6.8249526024, 8.8183727264])
# Iter 369; theta =  tensor([6.8266854286, 8.8201513290])
# Iter 370; theta =  tensor([6.8284010887, 8.8219127655])
# Iter 371; theta =  tensor([6.8300995827, 8.8236570358])
# Iter 372; theta =  tensor([6.8317813873, 8.8253841400])
# Iter 373; theta =  tensor([6.8334465027, 8.8270940781])
# Iter 374; theta =  tensor([6.8350954056, 8.8287878036])
# Iter 375; theta =  tensor([6.8367276192, 8.8304653168])
# Iter 376; theta =  tensor([6.8383440971, 8.8321256638])
# Iter 377; theta =  tensor([6.8399443626, 8.8337697983])
# Iter 378; theta =  tensor([6.8415288925, 8.8353977203])
# Iter 379; theta =  tensor([6.8430976868, 8.8370103836])
# Iter 380; theta =  tensor([6.8446507454, 8.8386068344])
# Iter 381; theta =  tensor([6.8461885452, 8.8401880264])
# Iter 382; theta =  tensor([6.8477110863, 8.8417530060])
# Iter 383; theta =  tensor([6.8492188454, 8.8433027267])
# Iter 384; theta =  tensor([6.8507113457, 8.8448371887])
# Iter 385; theta =  tensor([6.8521890640, 8.8463573456])
# Iter 386; theta =  tensor([6.8536524773, 8.8478622437])
# Iter 387; theta =  tensor([6.8551011086, 8.8493528366])
# Iter 388; theta =  tensor([6.8565354347, 8.8508281708])
# Iter 389; theta =  tensor([6.8579554558, 8.8522891998])
# Iter 390; theta =  tensor([6.8593616486, 8.8537359238])
# Iter 391; theta =  tensor([6.8607540131, 8.8551683426])
# Iter 392; theta =  tensor([6.8621325493, 8.8565874100])
# Iter 393; theta =  tensor([6.8634972572, 8.8579921722])
# Iter 394; theta =  tensor([6.8648486137, 8.8593835831])
# Iter 395; theta =  tensor([6.8661866188, 8.8607606888])
# Iter 396; theta =  tensor([6.8675112724, 8.8621244431])
# Iter 397; theta =  tensor([6.8688225746, 8.8634748459])
# Iter 398; theta =  tensor([6.8701210022, 8.8648118973])
# Iter 399; theta =  tensor([6.8714065552, 8.8661365509])
# Iter 400; theta =  tensor([6.8726797104, 8.8674478531])
# Iter 401; theta =  tensor([6.8739399910, 8.8687458038])
# Iter 402; theta =  tensor([6.8751878738, 8.8700313568])
# Iter 403; theta =  tensor([6.8764233589, 8.8713045120])
# Iter 404; theta =  tensor([6.8776464462, 8.8725652695])
# Iter 405; theta =  tensor([6.8788576126, 8.8738136292])
# Iter 406; theta =  tensor([6.8800568581, 8.8750495911])
# Iter 407; theta =  tensor([6.8812441826, 8.8762731552])
# Iter 408; theta =  tensor([6.8824195862, 8.8774852753])
# Iter 409; theta =  tensor([6.8835835457, 8.8786849976])
# Iter 410; theta =  tensor([6.8847360611, 8.8798732758])
# Iter 411; theta =  tensor([6.8858771324, 8.8810501099])
# Iter 412; theta =  tensor([6.8870067596, 8.8822154999])
# Iter 413; theta =  tensor([6.8881254196, 8.8833694458])
# Iter 414; theta =  tensor([6.8892326355, 8.8845119476])
# Iter 415; theta =  tensor([6.8903288841, 8.8856430054])
# Iter 416; theta =  tensor([6.8914146423, 8.8867635727])
# Iter 417; theta =  tensor([6.8924894333, 8.8878726959])
# Iter 418; theta =  tensor([6.8935537338, 8.8889713287])
# Iter 419; theta =  tensor([6.8946075439, 8.8900585175])
# Iter 420; theta =  tensor([6.8956508636, 8.8911352158])
# Iter 421; theta =  tensor([6.8966836929, 8.8922014236])
# Iter 422; theta =  tensor([6.8977065086, 8.8932571411])
# Iter 423; theta =  tensor([6.8987193108, 8.8943023682])
# Iter 424; theta =  tensor([6.8997216225, 8.8953380585])
# Iter 425; theta =  tensor([6.9007143974, 8.8963632584])
# Iter 426; theta =  tensor([6.9016971588, 8.8973789215])
# Iter 427; theta =  tensor([6.9026703835, 8.8983840942])
# Iter 428; theta =  tensor([6.9036335945, 8.8993797302])
# Iter 429; theta =  tensor([6.9045872688, 8.9003658295])
# Iter 430; theta =  tensor([6.9055318832, 8.9013414383])
# Iter 431; theta =  tensor([6.9064669609, 8.9023075104])
# Iter 432; theta =  tensor([6.9073929787, 8.9032640457])
# Iter 433; theta =  tensor([6.9083094597, 8.9042119980])
# Iter 434; theta =  tensor([6.9092168808, 8.9051504135])
# Iter 435; theta =  tensor([6.9101157188, 8.9060792923])
# Iter 436; theta =  tensor([6.9110054970, 8.9069995880])
# Iter 437; theta =  tensor([6.9118862152, 8.9079103470])
# Iter 438; theta =  tensor([6.9127583504, 8.9088125229])
# Iter 439; theta =  tensor([6.9136219025, 8.9097061157])
# Iter 440; theta =  tensor([6.9144768715, 8.9105901718])
# Iter 441; theta =  tensor([6.9153232574, 8.9114656448])
# Iter 442; theta =  tensor([6.9161615372, 8.9123325348])
# Iter 443; theta =  tensor([6.9169912338, 8.9131908417])
# Iter 444; theta =  tensor([6.9178128242, 8.9140415192])
# Iter 445; theta =  tensor([6.9186263084, 8.9148836136])
# Iter 446; theta =  tensor([6.9194316864, 8.9157171249])
# Iter 447; theta =  tensor([6.9202289581, 8.9165430069])
# Iter 448; theta =  tensor([6.9210186005, 8.9173603058])
# Iter 449; theta =  tensor([6.9218006134, 8.9181699753])
# Iter 450; theta =  tensor([6.9225745201, 8.9189720154])
# Iter 451; theta =  tensor([6.9233407974, 8.9197654724])
# Iter 452; theta =  tensor([6.9240994453, 8.9205513000])
# Iter 453; theta =  tensor([6.9248509407, 8.9213294983])
# Iter 454; theta =  tensor([6.9255948067, 8.9221000671])
# Iter 455; theta =  tensor([6.9263315201, 8.9228630066])
# Iter 456; theta =  tensor([6.9270606041, 8.9236183167])
# Iter 457; theta =  tensor([6.9277825356, 8.9243669510])
# Iter 458; theta =  tensor([6.9284973145, 8.9251079559])
# Iter 459; theta =  tensor([6.9292049408, 8.9258413315])
# Iter 460; theta =  tensor([6.9299058914, 8.9265680313])
# Iter 461; theta =  tensor([6.9305996895, 8.9272871017])
# Iter 462; theta =  tensor([6.9312868118, 8.9279994965])
# Iter 463; theta =  tensor([6.9319667816, 8.9287052155])
# Iter 464; theta =  tensor([6.9326400757, 8.9294033051])
# Iter 465; theta =  tensor([6.9333066940, 8.9300947189])
# Iter 466; theta =  tensor([6.9339666367, 8.9307794571])
# Iter 467; theta =  tensor([6.9346203804, 8.9314575195])
# Iter 468; theta =  tensor([6.9352674484, 8.9321289062])
# Iter 469; theta =  tensor([6.9359083176, 8.9327936172])
# Iter 470; theta =  tensor([6.9365425110, 8.9334516525])
# Iter 471; theta =  tensor([6.9371705055, 8.9341039658])
# Iter 472; theta =  tensor([6.9377923012, 8.9347496033])
# Iter 473; theta =  tensor([6.9384078979, 8.9353885651])
# Iter 474; theta =  tensor([6.9390177727, 8.9360218048])
# Iter 475; theta =  tensor([6.9396214485, 8.9366483688])
# Iter 476; theta =  tensor([6.9402189255, 8.9372692108])
# Iter 477; theta =  tensor([6.9408106804, 8.9378833771])
# Iter 478; theta =  tensor([6.9413967133, 8.9384918213])
# Iter 479; theta =  tensor([6.9419765472, 8.9390945435])
# Iter 480; theta =  tensor([6.9425506592, 8.9396915436])
# Iter 481; theta =  tensor([6.9431195259, 8.9402818680])
# Iter 482; theta =  tensor([6.9436826706, 8.9408664703])
# Iter 483; theta =  tensor([6.9442400932, 8.9414453506])
# Iter 484; theta =  tensor([6.9447917938, 8.9420185089])
# Iter 485; theta =  tensor([6.9453382492, 8.9425868988])
# Iter 486; theta =  tensor([6.9458794594, 8.9431495667])
# Iter 487; theta =  tensor([6.9464149475, 8.9437065125])
# Iter 488; theta =  tensor([6.9469451904, 8.9442577362])
# Iter 489; theta =  tensor([6.9474701881, 8.9448041916])
# Iter 490; theta =  tensor([6.9479899406, 8.9453449249])
# Iter 491; theta =  tensor([6.9485049248, 8.9458799362])
# Iter 492; theta =  tensor([6.9490146637, 8.9464101791])
# Iter 493; theta =  tensor([6.9495191574, 8.9469347000])
# Iter 494; theta =  tensor([6.9500188828, 8.9474544525])
# Iter 495; theta =  tensor([6.9505133629, 8.9479694366])
# Iter 496; theta =  tensor([6.9510030746, 8.9484786987])
# Iter 497; theta =  tensor([6.9514880180, 8.9489831924])
# Iter 498; theta =  tensor([6.9519681931, 8.9494829178])
# Iter 499; theta =  tensor([6.9524435997, 8.9499778748])
# Iter 500; theta =  tensor([6.9529142380, 8.9504680634])
# Iter 501; theta =  tensor([6.9533801079, 8.9509534836])
# Iter 502; theta =  tensor([6.9538416862, 8.9514341354])
# Iter 503; theta =  tensor([6.9542984962, 8.9519100189])
# Iter 504; theta =  tensor([6.9547510147, 8.9523811340])
# Iter 505; theta =  tensor([6.9551987648, 8.9528474808])
# Iter 506; theta =  tensor([6.9556422234, 8.9533090591])
# Iter 507; theta =  tensor([6.9560813904, 8.9537668228])
# Iter 508; theta =  tensor([6.9565162659, 8.9542198181])
# Iter 509; theta =  tensor([6.9569468498, 8.9546680450])
# Iter 510; theta =  tensor([6.9573731422, 8.9551124573])
# Iter 511; theta =  tensor([6.9577951431, 8.9555521011])
# Iter 512; theta =  tensor([6.9582128525, 8.9559879303])
# Iter 513; theta =  tensor([6.9586262703, 8.9564189911])
# Iter 514; theta =  tensor([6.9590358734, 8.9568462372])
# Iter 515; theta =  tensor([6.9594411850, 8.9572687149])
# Iter 516; theta =  tensor([6.9598426819, 8.9576873779])
# Iter 517; theta =  tensor([6.9602403641, 8.9581022263])
# Iter 518; theta =  tensor([6.9606337547, 8.9585123062])
# Iter 519; theta =  tensor([6.9610233307, 8.9589185715])
# Iter 520; theta =  tensor([6.9614090919, 8.9593210220])
# Iter 521; theta =  tensor([6.9617910385, 8.9597196579])
# Iter 522; theta =  tensor([6.9621691704, 8.9601144791])
# Iter 523; theta =  tensor([6.9625434875, 8.9605054855])
# Iter 524; theta =  tensor([6.9629139900, 8.9608926773])
# Iter 525; theta =  tensor([6.9632811546, 8.9612760544])
# Iter 526; theta =  tensor([6.9636445045, 8.9616556168])
# Iter 527; theta =  tensor([6.9640045166, 8.9620313644])
# Iter 528; theta =  tensor([6.9643607140, 8.9624032974])
# Iter 529; theta =  tensor([6.9647135735, 8.9627714157])
# Iter 530; theta =  tensor([6.9650626183, 8.9631357193])
# Iter 531; theta =  tensor([6.9654083252, 8.9634971619])
# Iter 532; theta =  tensor([6.9657506943, 8.9638547897])
# Iter 533; theta =  tensor([6.9660897255, 8.9642086029])
# Iter 534; theta =  tensor([6.9664254189, 8.9645595551])
# Iter 535; theta =  tensor([6.9667577744, 8.9649066925])
# Iter 536; theta =  tensor([6.9670867920, 8.9652500153])
# Iter 537; theta =  tensor([6.9674124718, 8.9655904770])
# Iter 538; theta =  tensor([6.9677348137, 8.9659271240])
# Iter 539; theta =  tensor([6.9680542946, 8.9662609100])
# Iter 540; theta =  tensor([6.9683704376, 8.9665918350])
# Iter 541; theta =  tensor([6.9686837196, 8.9669189453])
# Iter 542; theta =  tensor([6.9689936638, 8.9672431946])
# Iter 543; theta =  tensor([6.9693007469, 8.9675636292])
# Iter 544; theta =  tensor([6.9696044922, 8.9678812027])
# Iter 545; theta =  tensor([6.9699053764, 8.9681959152])
# Iter 546; theta =  tensor([6.9702033997, 8.9685077667])
# Iter 547; theta =  tensor([6.9704980850, 8.9688167572])
# Iter 548; theta =  tensor([6.9707899094, 8.9691219330])
# Iter 549; theta =  tensor([6.9710788727, 8.9694242477])
# Iter 550; theta =  tensor([6.9713649750, 8.9697237015])
# Iter 551; theta =  tensor([6.9716482162, 8.9700202942])
# Iter 552; theta =  tensor([6.9719285965, 8.9703140259])
# Iter 553; theta =  tensor([6.9722065926, 8.9706048965])
# Iter 554; theta =  tensor([6.9724817276, 8.9708929062])
# Iter 555; theta =  tensor([6.9727540016, 8.9711780548])
# Iter 556; theta =  tensor([6.9730238914, 8.9714603424])
# Iter 557; theta =  tensor([6.9732909203, 8.9717397690])
# Iter 558; theta =  tensor([6.9735550880, 8.9720163345])
# Iter 559; theta =  tensor([6.9738168716, 8.9722900391])
# Iter 560; theta =  tensor([6.9740757942, 8.9725618362])
# Iter 561; theta =  tensor([6.9743323326, 8.9728307724])
# Iter 562; theta =  tensor([6.9745864868, 8.9730968475])
# Iter 563; theta =  tensor([6.9748377800, 8.9733600616])
# Iter 564; theta =  tensor([6.9750866890, 8.9736213684])
# Iter 565; theta =  tensor([6.9753332138, 8.9738798141])
# Iter 566; theta =  tensor([6.9755773544, 8.9741353989])
# Iter 567; theta =  tensor([6.9758191109, 8.9743890762])
# Iter 568; theta =  tensor([6.9760584831, 8.9746398926])
# Iter 569; theta =  tensor([6.9762954712, 8.9748888016])
# Iter 570; theta =  tensor([6.9765300751, 8.9751348495])
# Iter 571; theta =  tensor([6.9767622948, 8.9753780365])
# Iter 572; theta =  tensor([6.9769921303, 8.9756193161])
# Iter 573; theta =  tensor([6.9772200584, 8.9758577347])
# Iter 574; theta =  tensor([6.9774456024, 8.9760942459])
# Iter 575; theta =  tensor([6.9776687622, 8.9763288498])
# Iter 576; theta =  tensor([6.9778900146, 8.9765605927])
# Iter 577; theta =  tensor([6.9781088829, 8.9767904282])
# Iter 578; theta =  tensor([6.9783253670, 8.9770174026])
# Iter 579; theta =  tensor([6.9785399437, 8.9772424698])
# Iter 580; theta =  tensor([6.9787521362, 8.9774656296])
# Iter 581; theta =  tensor([6.9789624214, 8.9776859283])
# Iter 582; theta =  tensor([6.9791707993, 8.9779043198])
# Iter 583; theta =  tensor([6.9793767929, 8.9781208038])
# Iter 584; theta =  tensor([6.9795808792, 8.9783353806])
# Iter 585; theta =  tensor([6.9797830582, 8.9785480499])
# Iter 586; theta =  tensor([6.9799833298, 8.9787578583])
# Iter 587; theta =  tensor([6.9801812172, 8.9789657593])
# Iter 588; theta =  tensor([6.9803771973, 8.9791717529])
# Iter 589; theta =  tensor([6.9805712700, 8.9793758392])
# Iter 590; theta =  tensor([6.9807634354, 8.9795780182])
# Iter 591; theta =  tensor([6.9809536934, 8.9797782898])
# Iter 592; theta =  tensor([6.9811420441, 8.9799766541])
# Iter 593; theta =  tensor([6.9813284874, 8.9801731110])
# Iter 594; theta =  tensor([6.9815135002, 8.9803676605])
# Iter 595; theta =  tensor([6.9816966057, 8.9805603027])
# Iter 596; theta =  tensor([6.9818778038, 8.9807510376])
# Iter 597; theta =  tensor([6.9820570946, 8.9809398651])
# Iter 598; theta =  tensor([6.9822344780, 8.9811267853])
# Iter 599; theta =  tensor([6.9824104309, 8.9813117981])
# Iter 600; theta =  tensor([6.9825844765, 8.9814949036])
# Iter 601; theta =  tensor([6.9827566147, 8.9816761017])
# Iter 602; theta =  tensor([6.9829273224, 8.9818553925])
# Iter 603; theta =  tensor([6.9830961227, 8.9820327759])
# Iter 604; theta =  tensor([6.9832634926, 8.9822092056])
# Iter 605; theta =  tensor([6.9834289551, 8.9823837280])
# Iter 606; theta =  tensor([6.9835929871, 8.9825563431])
# Iter 607; theta =  tensor([6.9837555885, 8.9827270508])
# Iter 608; theta =  tensor([6.9839162827, 8.9828958511])
# Iter 609; theta =  tensor([6.9840755463, 8.9830636978])
# Iter 610; theta =  tensor([6.9842333794, 8.9832296371])
# Iter 611; theta =  tensor([6.9843893051, 8.9833936691])
# Iter 612; theta =  tensor([6.9845438004, 8.9835567474])
# Iter 613; theta =  tensor([6.9846968651, 8.9837179184])

# %%
theta
# Out:
# tensor([6.9846968651, 8.9837179184], requires_grad=True)

# %% [markdown]
# 12. Altere a função de Gradiente Descendente para funcionar com minibatches. Em outras palavras, não compute o erro usando todos os dados de X. Use um `slice` de tamanho do minibatch. Uma ideia é seguir o pseudocódigo abaixo.
#
# ```python
# index = np.arange(len(X))
# while True:
#     minib = np.random.choice(index, minibatchsize) # aqui estou usando numpy para selection minibatch elementos
#     X_batch = X[minib]
# ```

# %%
# Exemplo abaixo
index = np.arange(len(X))
mb = np.random.choice(index, 50)
print(mb)
X[mb]
# Out:
# [188 466 816 317 761 621 210 911 304  51 381 534 712 869 955 781 316 717
#  177 874 277 120 481  96 904 857 730  66  75 501 831   2 271 773 731 697
#  177 150 712 845 644  12 592 878  74 824 884 406 444 122]
# tensor([[ 1.0000000000, -0.2452588081],
#         [ 1.0000000000, -0.2808489799],
#         [ 1.0000000000,  1.9988949299],
#         [ 1.0000000000,  0.6723055243],
#         [ 1.0000000000, -0.2024962604],
#         [ 1.0000000000, -1.1705948114],
#         [ 1.0000000000,  2.2508692741],
#         [ 1.0000000000, -0.2576732934],
#         [ 1.0000000000,  1.5019823313],
#         [ 1.0000000000, -0.9672911763],
#         [ 1.0000000000,  0.9368112087],
#         [ 1.0000000000,  0.1672501862],
#         [ 1.0000000000, -0.3064432442],
#         [ 1.0000000000,  1.2376105785],
#         [ 1.0000000000, -0.0923149586],
#         [ 1.0000000000, -0.6847057939],
#         [ 1.0000000000, -0.1414243430],
#         [ 1.0000000000, -0.2493717521],
#         [ 1.0000000000, -1.2754817009],
#         [ 1.0000000000,  0.3747464716],
#         [ 1.0000000000, -0.0269862022],
#         [ 1.0000000000,  0.6756001115],
#         [ 1.0000000000, -0.4644445181],
#         [ 1.0000000000, -0.3804849088],
#         [ 1.0000000000,  0.6317514181],
#         [ 1.0000000000,  0.4653484225],
#         [ 1.0000000000, -0.3454351425],
#         [ 1.0000000000,  0.0574304946],
#         [ 1.0000000000,  1.5344345570],
#         [ 1.0000000000, -0.2558572292],
#         [ 1.0000000000, -0.2174325436],
#         [ 1.0000000000,  0.3329448402],
#         [ 1.0000000000,  1.2375535965],
#         [ 1.0000000000, -1.5129865408],
#         [ 1.0000000000,  1.1278390884],
#         [ 1.0000000000,  1.2300605774],
#         [ 1.0000000000, -1.2754817009],
#         [ 1.0000000000,  2.2639861107],
#         [ 1.0000000000, -0.3064432442],
#         [ 1.0000000000, -0.8178967237],
#         [ 1.0000000000,  0.4893335998],
#         [ 1.0000000000,  0.8029308319],
#         [ 1.0000000000,  0.6197313666],
#         [ 1.0000000000, -0.2901527584],
#         [ 1.0000000000,  0.0639475957],
#         [ 1.0000000000,  1.6451666355],
#         [ 1.0000000000, -1.2617055178],
#         [ 1.0000000000, -1.3650783300],
#         [ 1.0000000000,  0.0685203373],
#         [ 1.0000000000,  1.0128425360]])

# %%
def minibatch_gd(d_fun, loss_fun, X, y, lambda_=0.01, tol=0.00001,
                 max_iter=10000, batch_size=50):
    '''
    Executa Gradiente Descendente. Aqui:
    
    Parâmetros
    ----------
    d_fun : é uma função de derivadas
    loss_fun : é uma função de perda
    X : é um vetor de fatores explanatórios.
        Copie seu código de intercepto da primeira aula.
        para adicionar o intercepto em X.
    y : é a resposta
    lambda : é a taxa de aprendizad
    tol : é a tolerância, define quando o algoritmo vai parar.
    max_ter : é a segunda forma de parada, mesmo sem convergir
              paramos depois de max_iter iterações.
    batch_size : tamanho do batch
    '''
    theta = torch.randn(X.shape[1]).double()
    theta.requires_grad_(True)
    print('Iter {}; theta = '.format(0), theta)
    old_err_sq = np.inf
    i = 0
    
    index = np.arange(len(X))
    while True:
        theta.requires_grad_(True)
        # pega o mini batch
        mb = np.random.choice(index, batch_size)
        Xmb = X[mb]
        ymb = y[mb]
        
        # Computar as derivadas
        grad = d_fun(Xmb, theta, ymb)
        # Atualizar
        with torch.no_grad():
            theta_novo = theta - lambda_ * grad
        
        # Parar quando o erro convergir
        err_sq = loss_fun(Xmb, theta, ymb)
        if torch.abs(old_err_sq - err_sq) <= tol:
            break
        
        # Atualizar parâmetros e erro
        theta = theta_novo
        old_err_sq = err_sq
        
        # Informação de debug
        print('Iter {}; theta = '.format(i+1), theta)
        i += 1
        if i == max_iter:
            break
    return theta

# %%
# Sua função deve retornar algo perto de 7 e 9
minibatch_gd(derivada_torch, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =  tensor([-0.4376114607, -2.1191031933], dtype=torch.float64, requires_grad=True)
# Iter 1; theta =  tensor([-0.2939185381, -1.9499445820], dtype=torch.float64)
# Iter 2; theta =  tensor([-0.1385552549, -1.7532149982], dtype=torch.float64)
# Iter 3; theta =  tensor([ 0.0053728247, -1.5674544811], dtype=torch.float64)
# Iter 4; theta =  tensor([ 0.1093092966, -1.3437399769], dtype=torch.float64)
# Iter 5; theta =  tensor([ 0.2393841887, -1.1359491825], dtype=torch.float64)
# Iter 6; theta =  tensor([ 0.3624006319, -0.8583090878], dtype=torch.float64)
# Iter 7; theta =  tensor([ 0.5316620111, -0.6222730923], dtype=torch.float64)
# Iter 8; theta =  tensor([ 0.6493402433, -0.4257868671], dtype=torch.float64)
# Iter 9; theta =  tensor([ 0.7459002638, -0.2313262653], dtype=torch.float64)
# Iter 10; theta =  tensor([ 0.8485105181, -0.0167105770], dtype=torch.float64)
# Iter 11; theta =  tensor([0.9389146757, 0.1358383083], dtype=torch.float64)
# Iter 12; theta =  tensor([1.0572591352, 0.3211669254], dtype=torch.float64)
# Iter 13; theta =  tensor([1.1788378477, 0.5024773884], dtype=torch.float64)
# Iter 14; theta =  tensor([1.2708457804, 0.6107333565], dtype=torch.float64)
# Iter 15; theta =  tensor([1.3573556948, 0.7744149590], dtype=torch.float64)
# Iter 16; theta =  tensor([1.4725208521, 0.9223848248], dtype=torch.float64)
# Iter 17; theta =  tensor([1.5678562498, 1.1203085804], dtype=torch.float64)
# Iter 18; theta =  tensor([1.6670628405, 1.2233301830], dtype=torch.float64)
# Iter 19; theta =  tensor([1.7715592146, 1.3457631588], dtype=torch.float64)
# Iter 20; theta =  tensor([1.8619124269, 1.4783235645], dtype=torch.float64)
# Iter 21; theta =  tensor([1.9498307943, 1.5914158726], dtype=torch.float64)
# Iter 22; theta =  tensor([2.0752641821, 1.7538785648], dtype=torch.float64)
# Iter 23; theta =  tensor([2.1650699568, 1.8880753231], dtype=torch.float64)
# Iter 24; theta =  tensor([2.2476495123, 1.9641920710], dtype=torch.float64)
# Iter 25; theta =  tensor([2.3658845949, 2.1333557749], dtype=torch.float64)
# Iter 26; theta =  tensor([2.4626878691, 2.2644043875], dtype=torch.float64)
# Iter 27; theta =  tensor([2.5674983740, 2.4588270330], dtype=torch.float64)
# Iter 28; theta =  tensor([2.6890172625, 2.6394433165], dtype=torch.float64)
# Iter 29; theta =  tensor([2.7601342964, 2.8020920134], dtype=torch.float64)
# Iter 30; theta =  tensor([2.8506407452, 2.9178869963], dtype=torch.float64)
# Iter 31; theta =  tensor([2.9392266369, 3.0447749758], dtype=torch.float64)
# Iter 32; theta =  tensor([3.0300623608, 3.1614166784], dtype=torch.float64)
# Iter 33; theta =  tensor([3.1174892139, 3.2901377058], dtype=torch.float64)
# Iter 34; theta =  tensor([3.2042083168, 3.3942758226], dtype=torch.float64)
# Iter 35; theta =  tensor([3.2991489792, 3.5509932566], dtype=torch.float64)
# Iter 36; theta =  tensor([3.3655466175, 3.6370371962], dtype=torch.float64)
# Iter 37; theta =  tensor([3.4416797161, 3.7115159798], dtype=torch.float64)
# Iter 38; theta =  tensor([3.5195679188, 3.8100945473], dtype=torch.float64)
# Iter 39; theta =  tensor([3.5845916986, 3.9021199703], dtype=torch.float64)
# Iter 40; theta =  tensor([3.6493548918, 4.0088937759], dtype=torch.float64)
# Iter 41; theta =  tensor([3.7191076994, 4.0997989273], dtype=torch.float64)
# Iter 42; theta =  tensor([3.7576203561, 4.1772970009], dtype=torch.float64)
# Iter 43; theta =  tensor([3.8059183145, 4.2727709007], dtype=torch.float64)
# Iter 44; theta =  tensor([3.8582053065, 4.3570828342], dtype=torch.float64)
# Iter 45; theta =  tensor([3.9099221587, 4.4454158020], dtype=torch.float64)
# Iter 46; theta =  tensor([3.9767495704, 4.5308907795], dtype=torch.float64)
# Iter 47; theta =  tensor([4.0445351005, 4.6051374340], dtype=torch.float64)
# Iter 48; theta =  tensor([4.0986833835, 4.6913876629], dtype=torch.float64)
# Iter 49; theta =  tensor([4.1373071027, 4.7869710827], dtype=torch.float64)
# Iter 50; theta =  tensor([4.1795487952, 4.8648478699], dtype=torch.float64)
# Iter 51; theta =  tensor([4.2413942218, 4.9716668606], dtype=torch.float64)
# Iter 52; theta =  tensor([4.2862529492, 5.0667545986], dtype=torch.float64)
# Iter 53; theta =  tensor([4.3448743606, 5.1519413376], dtype=torch.float64)
# Iter 54; theta =  tensor([4.4159215760, 5.2457599735], dtype=torch.float64)
# Iter 55; theta =  tensor([4.4470628166, 5.3126279879], dtype=torch.float64)
# Iter 56; theta =  tensor([4.4928408337, 5.3953705359], dtype=torch.float64)
# Iter 57; theta =  tensor([4.5423016453, 5.4768550539], dtype=torch.float64)
# Iter 58; theta =  tensor([4.5827897739, 5.5235469341], dtype=torch.float64)
# Iter 59; theta =  tensor([4.6399360657, 5.6195114517], dtype=torch.float64)
# Iter 60; theta =  tensor([4.6740223265, 5.6652844810], dtype=torch.float64)
# Iter 61; theta =  tensor([4.7186291838, 5.7332324982], dtype=torch.float64)
# Iter 62; theta =  tensor([4.7419590449, 5.8105717230], dtype=torch.float64)
# Iter 63; theta =  tensor([4.7907079434, 5.8711361790], dtype=torch.float64)
# Iter 64; theta =  tensor([4.8413064981, 5.9267287254], dtype=torch.float64)
# Iter 65; theta =  tensor([4.8907362342, 5.9727090025], dtype=torch.float64)
# Iter 66; theta =  tensor([4.9460094714, 6.0452068949], dtype=torch.float64)
# Iter 67; theta =  tensor([4.9820000315, 6.0980196762], dtype=torch.float64)
# Iter 68; theta =  tensor([5.0391206741, 6.1858991241], dtype=torch.float64)
# Iter 69; theta =  tensor([5.0863624430, 6.2417536879], dtype=torch.float64)
# Iter 70; theta =  tensor([5.1397331667, 6.3147922373], dtype=torch.float64)
# Iter 71; theta =  tensor([5.1800299597, 6.3693910789], dtype=torch.float64)
# Iter 72; theta =  tensor([5.2110102844, 6.4105700684], dtype=torch.float64)
# Iter 73; theta =  tensor([5.2422680449, 6.4564306927], dtype=torch.float64)
# Iter 74; theta =  tensor([5.2722605205, 6.4998191690], dtype=torch.float64)
# Iter 75; theta =  tensor([5.3001276064, 6.5322403502], dtype=torch.float64)
# Iter 76; theta =  tensor([5.3296171355, 6.5788497901], dtype=torch.float64)
# Iter 77; theta =  tensor([5.3661654949, 6.6106202006], dtype=torch.float64)
# Iter 78; theta =  tensor([5.3984215093, 6.6513180661], dtype=torch.float64)
# Iter 79; theta =  tensor([5.4150445282, 6.6966198039], dtype=torch.float64)
# Iter 80; theta =  tensor([5.4573123610, 6.7500773025], dtype=torch.float64)
# Iter 81; theta =  tensor([5.4857099593, 6.7834383488], dtype=torch.float64)
# Iter 82; theta =  tensor([5.5148429501, 6.8141839099], dtype=torch.float64)
# Iter 83; theta =  tensor([5.5377235496, 6.8374289227], dtype=torch.float64)
# Iter 84; theta =  tensor([5.5596738327, 6.8749799633], dtype=torch.float64)
# Iter 85; theta =  tensor([5.5992194593, 6.9347255802], dtype=torch.float64)
# Iter 86; theta =  tensor([5.6289591849, 6.9711625123], dtype=torch.float64)
# Iter 87; theta =  tensor([5.6476955903, 7.0137463450], dtype=torch.float64)
# Iter 88; theta =  tensor([5.6695154989, 7.0562279868], dtype=torch.float64)
# Iter 89; theta =  tensor([5.6885623848, 7.0889443851], dtype=torch.float64)
# Iter 90; theta =  tensor([5.7189810121, 7.1298054004], dtype=torch.float64)
# Iter 91; theta =  tensor([5.7523394907, 7.1696184802], dtype=torch.float64)
# Iter 92; theta =  tensor([5.7732749355, 7.2087943220], dtype=torch.float64)
# Iter 93; theta =  tensor([5.8012747586, 7.2461379004], dtype=torch.float64)
# Iter 94; theta =  tensor([5.8291444838, 7.2775167966], dtype=torch.float64)
# Iter 95; theta =  tensor([5.8564179122, 7.3097575641], dtype=torch.float64)
# Iter 96; theta =  tensor([5.8758131838, 7.3476095557], dtype=torch.float64)
# Iter 97; theta =  tensor([5.8984199548, 7.3788041973], dtype=torch.float64)
# Iter 98; theta =  tensor([5.9224201822, 7.4087210274], dtype=torch.float64)
# Iter 99; theta =  tensor([5.9413803267, 7.4435755682], dtype=torch.float64)
# Iter 100; theta =  tensor([5.9611927593, 7.4790677285], dtype=torch.float64)
# Iter 101; theta =  tensor([5.9854020107, 7.5059111619], dtype=torch.float64)
# Iter 102; theta =  tensor([5.9944549835, 7.5256239402], dtype=torch.float64)
# Iter 103; theta =  tensor([6.0070149815, 7.5508720434], dtype=torch.float64)
# Iter 104; theta =  tensor([6.0265804338, 7.5815666139], dtype=torch.float64)
# Iter 105; theta =  tensor([6.0470730662, 7.6053641307], dtype=torch.float64)
# Iter 106; theta =  tensor([6.0646551287, 7.6292333400], dtype=torch.float64)
# Iter 107; theta =  tensor([6.0780825067, 7.6484309256], dtype=torch.float64)
# Iter 108; theta =  tensor([6.0990051436, 7.6741686285], dtype=torch.float64)
# Iter 109; theta =  tensor([6.1131675637, 7.7068147027], dtype=torch.float64)
# Iter 110; theta =  tensor([6.1389741814, 7.7395533001], dtype=torch.float64)
# Iter 111; theta =  tensor([6.1561124468, 7.7599386895], dtype=torch.float64)
# Iter 112; theta =  tensor([6.1774516344, 7.7860981429], dtype=torch.float64)
# Iter 113; theta =  tensor([6.1934181046, 7.8058234179], dtype=torch.float64)
# Iter 114; theta =  tensor([6.2153049970, 7.8275154960], dtype=torch.float64)
# Iter 115; theta =  tensor([6.2303178883, 7.8456287825], dtype=torch.float64)
# Iter 116; theta =  tensor([6.2504919600, 7.8707969415], dtype=torch.float64)
# Iter 117; theta =  tensor([6.2660792685, 7.8922554576], dtype=torch.float64)
# Iter 118; theta =  tensor([6.2750198543, 7.9081767261], dtype=torch.float64)
# Iter 119; theta =  tensor([6.2904163659, 7.9355092394], dtype=torch.float64)
# Iter 120; theta =  tensor([6.3037640178, 7.9596457684], dtype=torch.float64)
# Iter 121; theta =  tensor([6.3140045464, 7.9742821956], dtype=torch.float64)
# Iter 122; theta =  tensor([6.3279219306, 7.9942122483], dtype=torch.float64)
# Iter 123; theta =  tensor([6.3446468902, 8.0144762063], dtype=torch.float64)
# Iter 124; theta =  tensor([6.3620985746, 8.0384613824], dtype=torch.float64)
# Iter 125; theta =  tensor([6.3766712558, 8.0551414490], dtype=torch.float64)
# Iter 126; theta =  tensor([6.3889722431, 8.0711889577], dtype=torch.float64)
# Iter 127; theta =  tensor([6.4022995722, 8.0885969579], dtype=torch.float64)
# Iter 128; theta =  tensor([6.4135768926, 8.1049687779], dtype=torch.float64)
# Iter 129; theta =  tensor([6.4264481878, 8.1236583412], dtype=torch.float64)
# Iter 130; theta =  tensor([6.4458694458, 8.1470193398], dtype=torch.float64)
# Iter 131; theta =  tensor([6.4548220408, 8.1596531188], dtype=torch.float64)
# Iter 132; theta =  tensor([6.4629138333, 8.1738615632], dtype=torch.float64)
# Iter 133; theta =  tensor([6.4755657810, 8.1904421771], dtype=torch.float64)
# Iter 134; theta =  tensor([6.4881189913, 8.2102718353], dtype=torch.float64)
# Iter 135; theta =  tensor([6.5011815733, 8.2294234574], dtype=torch.float64)
# Iter 136; theta =  tensor([6.5123816293, 8.2423659134], dtype=torch.float64)
# Iter 137; theta =  tensor([6.5247517353, 8.2561817610], dtype=torch.float64)
# Iter 138; theta =  tensor([6.5349297124, 8.2663613117], dtype=torch.float64)
# Iter 139; theta =  tensor([6.5435759211, 8.2775236189], dtype=torch.float64)
# Iter 140; theta =  tensor([6.5521239489, 8.2915478206], dtype=torch.float64)
# Iter 141; theta =  tensor([6.5597029603, 8.3033848953], dtype=torch.float64)
# Iter 142; theta =  tensor([6.5686165035, 8.3142575002], dtype=torch.float64)
# Iter 143; theta =  tensor([6.5792262924, 8.3324257398], dtype=torch.float64)
# Iter 144; theta =  tensor([6.5877336758, 8.3481335020], dtype=torch.float64)
# Iter 145; theta =  tensor([6.5979284054, 8.3635514283], dtype=torch.float64)
# Iter 146; theta =  tensor([6.6030334795, 8.3759162676], dtype=torch.float64)
# Iter 147; theta =  tensor([6.6106011963, 8.3899304593], dtype=torch.float64)
# Iter 148; theta =  tensor([6.6194547510, 8.4025268877], dtype=torch.float64)
# Iter 149; theta =  tensor([6.6263843298, 8.4153598297], dtype=torch.float64)
# Iter 150; theta =  tensor([6.6313215169, 8.4288530242], dtype=torch.float64)
# Iter 151; theta =  tensor([6.6368897936, 8.4377269357], dtype=torch.float64)
# Iter 152; theta =  tensor([6.6420489332, 8.4470466852], dtype=torch.float64)
# Iter 153; theta =  tensor([6.6499186507, 8.4557779026], dtype=torch.float64)
# Iter 154; theta =  tensor([6.6575509545, 8.4664185035], dtype=torch.float64)
# Iter 155; theta =  tensor([6.6638738570, 8.4768537152], dtype=torch.float64)
# Iter 156; theta =  tensor([6.6694227335, 8.4885866678], dtype=torch.float64)
# Iter 157; theta =  tensor([6.6762678131, 8.4980698293], dtype=torch.float64)
# Iter 158; theta =  tensor([6.6836822900, 8.5082902139], dtype=torch.float64)
# Iter 159; theta =  tensor([6.6901495168, 8.5204660958], dtype=torch.float64)
# Iter 160; theta =  tensor([6.6969139090, 8.5332803923], dtype=torch.float64)
# Iter 161; theta =  tensor([6.7030010524, 8.5430043215], dtype=torch.float64)
# Iter 162; theta =  tensor([6.7112898877, 8.5520164108], dtype=torch.float64)
# Iter 163; theta =  tensor([6.7155792263, 8.5613143635], dtype=torch.float64)
# Iter 164; theta =  tensor([6.7211066940, 8.5692023677], dtype=torch.float64)
# Iter 165; theta =  tensor([6.7264487132, 8.5817438692], dtype=torch.float64)
# Iter 166; theta =  tensor([6.7315391043, 8.5889115500], dtype=torch.float64)
# Iter 167; theta =  tensor([6.7376085719, 8.5961457217], dtype=torch.float64)
# Iter 168; theta =  tensor([6.7422358301, 8.6031203812], dtype=torch.float64)
# Iter 169; theta =  tensor([6.7482693389, 8.6116070145], dtype=torch.float64)
# Iter 170; theta =  tensor([6.7510112756, 8.6213665330], dtype=torch.float64)
# Iter 171; theta =  tensor([6.7551149195, 8.6293618214], dtype=torch.float64)
# Iter 172; theta =  tensor([6.7625307357, 8.6418725574], dtype=torch.float64)
# Iter 173; theta =  tensor([6.7690511751, 8.6513794917], dtype=torch.float64)
# Iter 174; theta =  tensor([6.7735606822, 8.6574188524], dtype=torch.float64)
# Iter 175; theta =  tensor([6.7793023166, 8.6646234703], dtype=torch.float64)
# Iter 176; theta =  tensor([6.7839207229, 8.6733537030], dtype=torch.float64)
# Iter 177; theta =  tensor([6.7885505459, 8.6809688252], dtype=torch.float64)
# Iter 178; theta =  tensor([6.7908188811, 8.6879491228], dtype=torch.float64)
# Iter 179; theta =  tensor([6.7952173939, 8.6923966035], dtype=torch.float64)
# Iter 180; theta =  tensor([6.7990681976, 8.6982264212], dtype=torch.float64)
# Iter 181; theta =  tensor([6.8024662906, 8.7046703443], dtype=torch.float64)
# Iter 182; theta =  tensor([6.8072268817, 8.7104558972], dtype=torch.float64)
# Iter 183; theta =  tensor([6.8123603359, 8.7163359079], dtype=torch.float64)
# Iter 184; theta =  tensor([6.8143680231, 8.7206728110], dtype=torch.float64)
# Iter 185; theta =  tensor([6.8178006993, 8.7249175498], dtype=torch.float64)
# Iter 186; theta =  tensor([6.8223704197, 8.7317746434], dtype=torch.float64)
# Iter 187; theta =  tensor([6.8272226305, 8.7393275073], dtype=torch.float64)
# Iter 188; theta =  tensor([6.8313043274, 8.7438257715], dtype=torch.float64)
# Iter 189; theta =  tensor([6.8355889539, 8.7491804722], dtype=torch.float64)
# Iter 190; theta =  tensor([6.8393483303, 8.7553498420], dtype=torch.float64)
# Iter 191; theta =  tensor([6.8423471661, 8.7595601130], dtype=torch.float64)
# Iter 192; theta =  tensor([6.8455211686, 8.7647272694], dtype=torch.float64)
# Iter 193; theta =  tensor([6.8482374121, 8.7697818059], dtype=torch.float64)
# Iter 194; theta =  tensor([6.8515711869, 8.7742348880], dtype=torch.float64)
# Iter 195; theta =  tensor([6.8541480522, 8.7789078563], dtype=torch.float64)
# Iter 196; theta =  tensor([6.8574032064, 8.7827696443], dtype=torch.float64)
# Iter 197; theta =  tensor([6.8596755914, 8.7862661761], dtype=torch.float64)
# Iter 198; theta =  tensor([6.8622108023, 8.7903788820], dtype=torch.float64)
# Iter 199; theta =  tensor([6.8651386251, 8.7949770528], dtype=torch.float64)
# Iter 200; theta =  tensor([6.8679984660, 8.7987959027], dtype=torch.float64)
# Iter 201; theta =  tensor([6.8710113876, 8.8023078465], dtype=torch.float64)
# Iter 202; theta =  tensor([6.8735461263, 8.8054159659], dtype=torch.float64)
# Iter 203; theta =  tensor([6.8751722802, 8.8078591169], dtype=torch.float64)
# Iter 204; theta =  tensor([6.8773879616, 8.8107978992], dtype=torch.float64)
# Iter 205; theta =  tensor([6.8796277685, 8.8140009721], dtype=torch.float64)
# Iter 206; theta =  tensor([6.8832349320, 8.8192469992], dtype=torch.float64)
# Iter 207; theta =  tensor([6.8854523788, 8.8247674812], dtype=torch.float64)
# Iter 208; theta =  tensor([6.8869757964, 8.8273761509], dtype=torch.float64)
# Iter 209; theta =  tensor([6.8887928285, 8.8305492736], dtype=torch.float64)
# Iter 210; theta =  tensor([6.8907743603, 8.8336197324], dtype=torch.float64)
# Iter 211; theta =  tensor([6.8928089796, 8.8374647461], dtype=torch.float64)
# Iter 212; theta =  tensor([6.8948473841, 8.8408582129], dtype=torch.float64)
# Iter 213; theta =  tensor([6.8967595319, 8.8437241127], dtype=torch.float64)
# Iter 214; theta =  tensor([6.9001105948, 8.8484621359], dtype=torch.float64)
# Iter 215; theta =  tensor([6.9018581921, 8.8509505372], dtype=torch.float64)
# Iter 216; theta =  tensor([6.9047224352, 8.8541636460], dtype=torch.float64)
# Iter 217; theta =  tensor([6.9059765480, 8.8568941312], dtype=torch.float64)
# Iter 218; theta =  tensor([6.9078756870, 8.8603616448], dtype=torch.float64)
# Iter 219; theta =  tensor([6.9101140884, 8.8635551466], dtype=torch.float64)
# Iter 220; theta =  tensor([6.9115842380, 8.8652231021], dtype=torch.float64)
# Iter 221; theta =  tensor([6.9136695926, 8.8683408104], dtype=torch.float64)
# Iter 222; theta =  tensor([6.9154712012, 8.8711931850], dtype=torch.float64)
# Iter 223; theta =  tensor([6.9167012993, 8.8737261699], dtype=torch.float64)
# Iter 224; theta =  tensor([6.9182059301, 8.8767461903], dtype=torch.float64)
# Iter 225; theta =  tensor([6.9189623819, 8.8783334294], dtype=torch.float64)
# Iter 226; theta =  tensor([6.9202504490, 8.8806187242], dtype=torch.float64)
# Iter 227; theta =  tensor([6.9214604434, 8.8832341775], dtype=torch.float64)
# Iter 228; theta =  tensor([6.9232112289, 8.8849633290], dtype=torch.float64)
# Iter 229; theta =  tensor([6.9244145146, 8.8863030124], dtype=torch.float64)
# Iter 230; theta =  tensor([6.9256441905, 8.8884270038], dtype=torch.float64)
# Iter 231; theta =  tensor([6.9269429181, 8.8904636860], dtype=torch.float64)
# Iter 232; theta =  tensor([6.9282857370, 8.8920814852], dtype=torch.float64)
# Iter 233; theta =  tensor([6.9295213896, 8.8941163298], dtype=torch.float64)
# Iter 234; theta =  tensor([6.9311729810, 8.8963228947], dtype=torch.float64)
# Iter 235; theta =  tensor([6.9323667558, 8.8982798809], dtype=torch.float64)
# Iter 236; theta =  tensor([6.9340734209, 8.9008144766], dtype=torch.float64)
# Iter 237; theta =  tensor([6.9357669923, 8.9028114176], dtype=torch.float64)
# Iter 238; theta =  tensor([6.9370197862, 8.9050964849], dtype=torch.float64)
# Iter 239; theta =  tensor([6.9382579806, 8.9069379309], dtype=torch.float64)
# Iter 240; theta =  tensor([6.9398732293, 8.9084270376], dtype=torch.float64)
# Iter 241; theta =  tensor([6.9411190119, 8.9100961834], dtype=torch.float64)
# Iter 242; theta =  tensor([6.9420128139, 8.9124650982], dtype=torch.float64)
# Iter 243; theta =  tensor([6.9434041157, 8.9152626020], dtype=torch.float64)
# Iter 244; theta =  tensor([6.9444372241, 8.9164043234], dtype=torch.float64)
# Iter 245; theta =  tensor([6.9457834277, 8.9186382967], dtype=torch.float64)
# Iter 246; theta =  tensor([6.9468146993, 8.9198335183], dtype=torch.float64)
# Iter 247; theta =  tensor([6.9476246945, 8.9218583672], dtype=torch.float64)
# Iter 248; theta =  tensor([6.9487027451, 8.9230304500], dtype=torch.float64)
# Iter 249; theta =  tensor([6.9493181038, 8.9241387454], dtype=torch.float64)
# Iter 250; theta =  tensor([6.9500546801, 8.9256809555], dtype=torch.float64)
# Iter 251; theta =  tensor([6.9511949092, 8.9274678341], dtype=torch.float64)
# Iter 252; theta =  tensor([6.9521048991, 8.9283527814], dtype=torch.float64)
# Iter 253; theta =  tensor([6.9531241137, 8.9298874424], dtype=torch.float64)
# Iter 254; theta =  tensor([6.9544053929, 8.9316576548], dtype=torch.float64)
# Iter 255; theta =  tensor([6.9553285882, 8.9331166336], dtype=torch.float64)
# Iter 256; theta =  tensor([6.9561768521, 8.9345334420], dtype=torch.float64)
# Iter 257; theta =  tensor([6.9570180872, 8.9358309309], dtype=torch.float64)
# Iter 258; theta =  tensor([6.9580086451, 8.9371816853], dtype=torch.float64)
# Iter 259; theta =  tensor([6.9588298970, 8.9381438789], dtype=torch.float64)
# Iter 260; theta =  tensor([6.9596478231, 8.9393039376], dtype=torch.float64)
# Iter 261; theta =  tensor([6.9602797493, 8.9404568648], dtype=torch.float64)
# Iter 262; theta =  tensor([6.9611032066, 8.9419144305], dtype=torch.float64)
# Iter 263; theta =  tensor([6.9617213081, 8.9427290164], dtype=torch.float64)
# Iter 264; theta =  tensor([6.9622924558, 8.9441568002], dtype=torch.float64)
# Iter 265; theta =  tensor([6.9632658449, 8.9451277860], dtype=torch.float64)
# Iter 266; theta =  tensor([6.9640523687, 8.9457278962], dtype=torch.float64)
# Iter 267; theta =  tensor([6.9645105530, 8.9465148270], dtype=torch.float64)
# Iter 268; theta =  tensor([6.9653141323, 8.9474958768], dtype=torch.float64)
# Iter 269; theta =  tensor([6.9662874522, 8.9488106669], dtype=torch.float64)
# Iter 270; theta =  tensor([6.9668646511, 8.9502749033], dtype=torch.float64)
# Iter 271; theta =  tensor([6.9675091161, 8.9510818426], dtype=torch.float64)
# Iter 272; theta =  tensor([6.9682978692, 8.9521018791], dtype=torch.float64)
# Iter 273; theta =  tensor([6.9690260898, 8.9530766360], dtype=torch.float64)
# Iter 274; theta =  tensor([6.9696603574, 8.9540072261], dtype=torch.float64)
# Iter 275; theta =  tensor([6.9704034652, 8.9550073497], dtype=torch.float64)
# Iter 276; theta =  tensor([6.9709652388, 8.9557425171], dtype=torch.float64)
# Iter 277; theta =  tensor([6.9716430787, 8.9565837258], dtype=torch.float64)
# Iter 278; theta =  tensor([6.9721364276, 8.9575591979], dtype=torch.float64)
# Iter 279; theta =  tensor([6.9725742985, 8.9583074483], dtype=torch.float64)
# Iter 280; theta =  tensor([6.9729423628, 8.9589160222], dtype=torch.float64)
# Iter 281; theta =  tensor([6.9735137026, 8.9601725401], dtype=torch.float64)
# Iter 282; theta =  tensor([6.9739540533, 8.9610072643], dtype=torch.float64)
# Iter 283; theta =  tensor([6.9744873594, 8.9615462588], dtype=torch.float64)
# Iter 284; theta =  tensor([6.9748688651, 8.9619447196], dtype=torch.float64)
# Iter 285; theta =  tensor([6.9752609138, 8.9625163471], dtype=torch.float64)
# Iter 286; theta =  tensor([6.9756060162, 8.9635299212], dtype=torch.float64)
# Iter 287; theta =  tensor([6.9760596670, 8.9643834168], dtype=torch.float64)
# Iter 288; theta =  tensor([6.9764047134, 8.9651034686], dtype=torch.float64)
# Iter 289; theta =  tensor([6.9768176546, 8.9657227950], dtype=torch.float64)
# Iter 290; theta =  tensor([6.9771171629, 8.9661049187], dtype=torch.float64)
# Iter 291; theta =  tensor([6.9776118388, 8.9666920959], dtype=torch.float64)
# Iter 292; theta =  tensor([6.9781419146, 8.9674954451], dtype=torch.float64)
# Iter 293; theta =  tensor([6.9786124567, 8.9680634930], dtype=torch.float64)
# Iter 294; theta =  tensor([6.9790583558, 8.9685970514], dtype=torch.float64)
# Iter 295; theta =  tensor([6.9795111399, 8.9692817660], dtype=torch.float64)
# Iter 296; theta =  tensor([6.9798953722, 8.9696612602], dtype=torch.float64)
# Iter 297; theta =  tensor([6.9800866555, 8.9699854488], dtype=torch.float64)
# Iter 298; theta =  tensor([6.9805315518, 8.9705346622], dtype=torch.float64)
# Iter 299; theta =  tensor([6.9809385234, 8.9713598968], dtype=torch.float64)
# Iter 300; theta =  tensor([6.9813828239, 8.9719090246], dtype=torch.float64)
# Iter 301; theta =  tensor([6.9817992753, 8.9723640255], dtype=torch.float64)
# Iter 302; theta =  tensor([6.9822779003, 8.9730725497], dtype=torch.float64)
# Iter 303; theta =  tensor([6.9826690895, 8.9737329356], dtype=torch.float64)
# Iter 304; theta =  tensor([6.9829660907, 8.9741329569], dtype=torch.float64)
# Iter 305; theta =  tensor([6.9832216723, 8.9744603057], dtype=torch.float64)
# Iter 306; theta =  tensor([6.9835966230, 8.9748492806], dtype=torch.float64)
# Iter 307; theta =  tensor([6.9838293208, 8.9755548432], dtype=torch.float64)
# Iter 308; theta =  tensor([6.9840773593, 8.9761669730], dtype=torch.float64)
# Iter 309; theta =  tensor([6.9843125959, 8.9767077776], dtype=torch.float64)
# tensor([6.9843125959, 8.9767077776], dtype=torch.float64, requires_grad=True)

# %% [markdown]
# ## Conjunto de Problemas 3: Logistic from Scratch

# %% [markdown]
# 12. Repita o mesmo processo para a Logística. Lembrando que a mesma tem a seguinte forma:
#
# $$f(x_i) = \frac{1}{1 + e^{-(1 + \theta_1 x_{i1} + \theta_2 x_{i2} + \cdots \theta_k x_{ik})}}$$
#
# Implemente a função logística.

# %%
def logistic(X, theta):
    return 1.0 / (1 + torch.exp(-torch.matmul(X, theta)))

# %%
# testes, não apague!
X_teste = torch.randn(1000, 20000)
theta = torch.randn(20000)
y_hat_teste = logistic(X_teste, theta)
assert_equal(True, (y_hat_teste >= 0).numpy().all())
assert_equal(True, (y_hat_teste <= 1).numpy().all())

# %% [markdown]
# Usando a logística acima implemente uma função logistica_prever que retorna 0 ou 1. Use o limiar dado na função.

# %%
def logistica_prever(X, theta, limiar=0.5):
    return logistic(X, theta) > limiar

# %%
# testes, não apague!
X_teste = torch.randn(1000, 20000)
theta = torch.randn(20000)
y_hat_teste = logistica_prever(X_teste, theta)
for yi in y_hat_teste.numpy():
    assert(yi in {0, 1})

# %% [markdown]
# Agora, implemente uma função de entropia cruzada da logística. A mesma, é proporcional ao inverso da verossimilhança. Para entender a derivação entre as duas faça uso dos [Slides](https://docs.google.com/presentation/d/1yGPETPe8o7PPOP6_CF38LHr3vpxgTEnF5LjP-1pkGIc/edit?usp=sharing).
#
# Sendo:
#
# $$ll(x_i,y_i~|~\theta) = y_i \log f(x_i\theta) + (1-y_i) \log (1-f(x_i\theta))$$
#
# A verossimilhança para uma observação. A entropia cruzada é a media da negação do termo para todos os exemplos:
#
# $$L(\theta) = -n^{-1}\sum_i \big((1-y_i)\log (1-f_{\theta}(x_i)) + y_i\log (f_{\theta}(x_i))\big)$$
#
# `dica: use torch.clamp(logistic(X, theta), min = 0.001, max = 0.999)`. A função remove os 0 e 1s da logistic, evitando assim o valor log(0).

# %%
def cross_entropy_mean(X, theta, y):
    logit = logistic(X, theta)
    logit = torch.clamp(logit, min=0.00001, max = 0.99999)
    return -(y * torch.log(logit) + (1 - y) * torch.log(1 - logit)).mean()

# %%
# testes, não apague!
from sklearn import datasets
state = np.random.seed(20190187)

X, y = datasets.make_blobs(n_samples=200, n_features=2, centers=2)
X = torch.tensor(X).double()
y = torch.tensor(y).double()

for _ in range(100):
    theta = torch.randn(2,1).double()
    assert(cross_entropy_mean(X, theta, y) >= 0)

# %% [markdown]
# Agora implemente a derivada.

# %%
def derivada_torch_logit(X, theta, y):
    e = cross_entropy_mean(X, theta, y)
    e.backward()
    return theta.grad

# %% [markdown]
# A partir daqui basta executar código.

# %%
plt.scatter(X.numpy()[:, 0], X.numpy()[:, 1], s=80, edgecolors='k')

# %% [markdown]
# 13. Assim como foi feito na primeira aula, abaixo testamos o seu código com um toy dataset.

# %%
# Use essa função antes de executar o GD
def add_intercept(X):
    Xn = torch.zeros(X.shape[0], X.shape[1] + 1).double()
    Xn[:, 0]  = 1.0
    Xn[:, 1:] = X
    return Xn

# %%
Xn = add_intercept(X)
theta = minibatch_gd(derivada_torch_logit, cross_entropy_mean, Xn, y)
# Out:
# Iter 0; theta =  tensor([-0.8399552107, -0.1420793831, -0.2658282518], dtype=torch.float64,
#        requires_grad=True)
# Iter 1; theta =  tensor([-0.8362851180, -0.1517247795, -0.2184974017], dtype=torch.float64)
# Iter 2; theta =  tensor([-0.8328364320, -0.1608919324, -0.1743527786], dtype=torch.float64)
# Iter 3; theta =  tensor([-0.8288615336, -0.1692674491, -0.1278573931], dtype=torch.float64)
# Iter 4; theta =  tensor([-0.8253997791, -0.1755219653, -0.0868603709], dtype=torch.float64)
# Iter 5; theta =  tensor([-0.8221447727, -0.1824855861, -0.0478664512], dtype=torch.float64)
# Iter 6; theta =  tensor([-0.8193639965, -0.1899631917, -0.0122580904], dtype=torch.float64)
# Iter 7; theta =  tensor([-0.8169536821, -0.1952350352,  0.0191253862], dtype=torch.float64)
# Iter 8; theta =  tensor([-0.8141142472, -0.2003333412,  0.0523291178], dtype=torch.float64)
# Iter 9; theta =  tensor([-0.8118748767, -0.2057533156,  0.0806829591], dtype=torch.float64)
# Iter 10; theta =  tensor([-0.8096016757, -0.2097412167,  0.1075693120], dtype=torch.float64)
# Iter 11; theta =  tensor([-0.8083780372, -0.2142061503,  0.1258207222], dtype=torch.float64)
# Iter 12; theta =  tensor([-0.8072618697, -0.2182271549,  0.1425474421], dtype=torch.float64)
# Iter 13; theta =  tensor([-0.8060175739, -0.2219636249,  0.1603140873], dtype=torch.float64)
# Iter 14; theta =  tensor([-0.8055409116, -0.2258959735,  0.1717422034], dtype=torch.float64)
# Iter 15; theta =  tensor([-0.8050585322, -0.2297499697,  0.1827590594], dtype=torch.float64)
# Iter 16; theta =  tensor([-0.8040296770, -0.2327416695,  0.1969014316], dtype=torch.float64)
# Iter 17; theta =  tensor([-0.8034849065, -0.2360604198,  0.2074358283], dtype=torch.float64)
# Iter 18; theta =  tensor([-0.8028029626, -0.2391059559,  0.2186333393], dtype=torch.float64)
# Iter 19; theta =  tensor([-0.8023489163, -0.2420716297,  0.2280258380], dtype=torch.float64)
# Iter 20; theta =  tensor([-0.8022112607, -0.2454165734,  0.2350052024], dtype=torch.float64)
# Iter 21; theta =  tensor([-0.8017922370, -0.2480504177,  0.2436133895], dtype=torch.float64)
# Iter 22; theta =  tensor([-0.8014047221, -0.2507784491,  0.2512408112], dtype=torch.float64)
# Iter 23; theta =  tensor([-0.8011113098, -0.2534977592,  0.2583636840], dtype=torch.float64)
# Iter 24; theta =  tensor([-0.8008321487, -0.2560281553,  0.2654149800], dtype=torch.float64)
# Iter 25; theta =  tensor([-0.8005577708, -0.2583733244,  0.2723732046], dtype=torch.float64)
# Iter 26; theta =  tensor([-0.7999370870, -0.2601290088,  0.2807495799], dtype=torch.float64)
# Iter 27; theta =  tensor([-0.7998533620, -0.2626298566,  0.2862672825], dtype=torch.float64)
# Iter 28; theta =  tensor([-0.7996482314, -0.2648505752,  0.2921257379], dtype=torch.float64)
# Iter 29; theta =  tensor([-0.7996112591, -0.2673946917,  0.2970319410], dtype=torch.float64)
# Iter 30; theta =  tensor([-0.7995461647, -0.2697376533,  0.3022249541], dtype=torch.float64)
# Iter 31; theta =  tensor([-0.7996450437, -0.2722631567,  0.3060889247], dtype=torch.float64)
# Iter 32; theta =  tensor([-0.7994347623, -0.2740090809,  0.3113744307], dtype=torch.float64)
# Iter 33; theta =  tensor([-0.7992167064, -0.2758320010,  0.3164242184], dtype=torch.float64)
# Iter 34; theta =  tensor([-0.7992025944, -0.2780538285,  0.3205982169], dtype=torch.float64)
# Iter 35; theta =  tensor([-0.7991853141, -0.2801188251,  0.3246017578], dtype=torch.float64)
# Iter 36; theta =  tensor([-0.7992722689, -0.2823365322,  0.3281867694], dtype=torch.float64)
# Iter 37; theta =  tensor([-0.7989792944, -0.2837193937,  0.3333161770], dtype=torch.float64)
# Iter 38; theta =  tensor([-0.7989872005, -0.2859279290,  0.3371406399], dtype=torch.float64)
# Iter 39; theta =  tensor([-0.7990593150, -0.2879410855,  0.3402447202], dtype=torch.float64)
# Iter 40; theta =  tensor([-0.7991236464, -0.2899850802,  0.3435511082], dtype=torch.float64)
# Iter 41; theta =  tensor([-0.7990953615, -0.2917280452,  0.3470377362], dtype=torch.float64)
# Iter 42; theta =  tensor([-0.7988092184, -0.2929178654,  0.3516615461], dtype=torch.float64)
# Iter 43; theta =  tensor([-0.7986590988, -0.2943807569,  0.3552935003], dtype=torch.float64)
# Iter 44; theta =  tensor([-0.7987479988, -0.2962364472,  0.3580275422], dtype=torch.float64)
# Iter 45; theta =  tensor([-0.7988334307, -0.2980944837,  0.3610174423], dtype=torch.float64)
# Iter 46; theta =  tensor([-0.7988705978, -0.2998698168,  0.3639475700], dtype=torch.float64)
# Iter 47; theta =  tensor([-0.7989329987, -0.3016368746,  0.3667754031], dtype=torch.float64)
# Iter 48; theta =  tensor([-0.7990208550, -0.3033132626,  0.3693584970], dtype=torch.float64)
# Iter 49; theta =  tensor([-0.7992109358, -0.3052171493,  0.3716356198], dtype=torch.float64)
# Iter 50; theta =  tensor([-0.7991744755, -0.3067124897,  0.3745093084], dtype=torch.float64)
# Iter 51; theta =  tensor([-0.7990712880, -0.3079091903,  0.3776540974], dtype=torch.float64)
# Iter 52; theta =  tensor([-0.7992075881, -0.3098679381,  0.3802970303], dtype=torch.float64)
# Iter 53; theta =  tensor([-0.7992548744, -0.3113861757,  0.3827769431], dtype=torch.float64)
# Iter 54; theta =  tensor([-0.7993104408, -0.3129927451,  0.3852458725], dtype=torch.float64)
# Iter 55; theta =  tensor([-0.7993106388, -0.3142141343,  0.3878609063], dtype=torch.float64)
# Iter 56; theta =  tensor([-0.7994269680, -0.3159376330,  0.3900896056], dtype=torch.float64)
# Iter 57; theta =  tensor([-0.7994844345, -0.3175635850,  0.3924710420], dtype=torch.float64)
# Iter 58; theta =  tensor([-0.7995368484, -0.3189677875,  0.3946927179], dtype=torch.float64)
# Iter 59; theta =  tensor([-0.7996521564, -0.3205132763,  0.3966123309], dtype=torch.float64)
# Iter 60; theta =  tensor([-0.7997153311, -0.3218772420,  0.3986425431], dtype=torch.float64)
# Iter 61; theta =  tensor([-0.7997921707, -0.3234046259,  0.4007296413], dtype=torch.float64)
# Iter 62; theta =  tensor([-0.7998044198, -0.3247135424,  0.4029488537], dtype=torch.float64)
# Iter 63; theta =  tensor([-0.7997788915, -0.3258223801,  0.4052056799], dtype=torch.float64)
# Iter 64; theta =  tensor([-0.7999745957, -0.3276861226,  0.4070232437], dtype=torch.float64)
# Iter 65; theta =  tensor([-0.8001609637, -0.3293157153,  0.4088375131], dtype=torch.float64)
# Iter 66; theta =  tensor([-0.8002795361, -0.3307829987,  0.4106479631], dtype=torch.float64)
# Iter 67; theta =  tensor([-0.8002678777, -0.3321140301,  0.4131751075], dtype=torch.float64)
# Iter 68; theta =  tensor([-0.8004186600, -0.3337429417,  0.4148309229], dtype=torch.float64)
# Iter 69; theta =  tensor([-0.8004663337, -0.3350081987,  0.4169558299], dtype=torch.float64)
# Iter 70; theta =  tensor([-0.8004939104, -0.3362586809,  0.4190295742], dtype=torch.float64)
# Iter 71; theta =  tensor([-0.8005241657, -0.3374932900,  0.4208905055], dtype=torch.float64)
# Iter 72; theta =  tensor([-0.8005085665, -0.3385875071,  0.4231787535], dtype=torch.float64)
# Iter 73; theta =  tensor([-0.8005848799, -0.3398813946,  0.4250406802], dtype=torch.float64)
# Iter 74; theta =  tensor([-0.8006634378, -0.3411280127,  0.4267452906], dtype=torch.float64)
# Iter 75; theta =  tensor([-0.8007531588, -0.3423425174,  0.4283850242], dtype=torch.float64)
# Iter 76; theta =  tensor([-0.8009002185, -0.3437240074,  0.4298452284], dtype=torch.float64)
# Iter 77; theta =  tensor([-0.8010861826, -0.3452344569,  0.4312629233], dtype=torch.float64)
# Iter 78; theta =  tensor([-0.8012962344, -0.3467338123,  0.4326147681], dtype=torch.float64)
# Iter 79; theta =  tensor([-0.8013631224, -0.3479423923,  0.4343467861], dtype=torch.float64)
# Iter 80; theta =  tensor([-0.8014755269, -0.3491761064,  0.4358086132], dtype=torch.float64)
# Iter 81; theta =  tensor([-0.8016545028, -0.3506368905,  0.4372491684], dtype=torch.float64)
# Iter 82; theta =  tensor([-0.8018026691, -0.3520176213,  0.4387502979], dtype=torch.float64)
# Iter 83; theta =  tensor([-0.8020394764, -0.3537234964,  0.4400196695], dtype=torch.float64)
# Iter 84; theta =  tensor([-0.8021371379, -0.3549296554,  0.4415499530], dtype=torch.float64)
# Iter 85; theta =  tensor([-0.8021814779, -0.3560293306,  0.4430783377], dtype=torch.float64)
# Iter 86; theta =  tensor([-0.8023017008, -0.3572959540,  0.4444147038], dtype=torch.float64)
# Iter 87; theta =  tensor([-0.8024985777, -0.3586849240,  0.4455245165], dtype=torch.float64)
# Iter 88; theta =  tensor([-0.8027368743, -0.3603164769,  0.4465702717], dtype=torch.float64)
# Iter 89; theta =  tensor([-0.8028653560, -0.3615114438,  0.4478539505], dtype=torch.float64)
# Iter 90; theta =  tensor([-0.8029368767, -0.3627101416,  0.4493859116], dtype=torch.float64)
# Iter 91; theta =  tensor([-0.8030766573, -0.3639088510,  0.4507394703], dtype=torch.float64)
# Iter 92; theta =  tensor([-0.8031288626, -0.3649399493,  0.4521624912], dtype=torch.float64)
# Iter 93; theta =  tensor([-0.8031350806, -0.3657887722,  0.4537527854], dtype=torch.float64)
# Iter 94; theta =  tensor([-0.8033287720, -0.3672424853,  0.4548509192], dtype=torch.float64)
# Iter 95; theta =  tensor([-0.8034164143, -0.3683900471,  0.4561041577], dtype=torch.float64)
# Iter 96; theta =  tensor([-0.8035564461, -0.3696972612,  0.4573790960], dtype=torch.float64)
# Iter 97; theta =  tensor([-0.8036966847, -0.3708485489,  0.4586025989], dtype=torch.float64)
# Iter 98; theta =  tensor([-0.8038379399, -0.3720860115,  0.4599313677], dtype=torch.float64)
# Iter 99; theta =  tensor([-0.8039539047, -0.3732182041,  0.4612232377], dtype=torch.float64)
# Iter 100; theta =  tensor([-0.8040018651, -0.3740377532,  0.4626090492], dtype=torch.float64)
# Iter 101; theta =  tensor([-0.8040081158, -0.3749529170,  0.4641640120], dtype=torch.float64)
# Iter 102; theta =  tensor([-0.8041451068, -0.3761001964,  0.4652562779], dtype=torch.float64)
# Iter 103; theta =  tensor([-0.8042953327, -0.3772710277,  0.4662226932], dtype=torch.float64)
# Iter 104; theta =  tensor([-0.8042953150, -0.3779994267,  0.4675833697], dtype=torch.float64)
# Iter 105; theta =  tensor([-0.8043281558, -0.3788421559,  0.4689099018], dtype=torch.float64)
# Iter 106; theta =  tensor([-0.8045284639, -0.3801720727,  0.4697691371], dtype=torch.float64)
# Iter 107; theta =  tensor([-0.8045220470, -0.3809742283,  0.4711954326], dtype=torch.float64)
# Iter 108; theta =  tensor([-0.8046445428, -0.3820857205,  0.4723615356], dtype=torch.float64)
# Iter 109; theta =  tensor([-0.8047143037, -0.3829563940,  0.4734283342], dtype=torch.float64)
# Iter 110; theta =  tensor([-0.8047723556, -0.3838482890,  0.4747207589], dtype=torch.float64)
# Iter 111; theta =  tensor([-0.8049196231, -0.3851018846,  0.4757755593], dtype=torch.float64)
# Iter 112; theta =  tensor([-0.8050011298, -0.3861140765,  0.4768951520], dtype=torch.float64)
# Iter 113; theta =  tensor([-0.8050037878, -0.3869227965,  0.4783195051], dtype=torch.float64)
# Iter 114; theta =  tensor([-0.8052804744, -0.3883802934,  0.4790731706], dtype=torch.float64)
# Iter 115; theta =  tensor([-0.8053749033, -0.3893202853,  0.4800874703], dtype=torch.float64)
# Iter 116; theta =  tensor([-0.8054301467, -0.3900976093,  0.4811850442], dtype=torch.float64)
# Iter 117; theta =  tensor([-0.8055046497, -0.3909959625,  0.4823098729], dtype=torch.float64)
# Iter 118; theta =  tensor([-0.8056379029, -0.3920479479,  0.4832093837], dtype=torch.float64)
# Iter 119; theta =  tensor([-0.8056331377, -0.3927616692,  0.4846292626], dtype=torch.float64)
# Iter 120; theta =  tensor([-0.8057126141, -0.3937044847,  0.4856681575], dtype=torch.float64)
# Iter 121; theta =  tensor([-0.8058605091, -0.3947385456,  0.4864889909], dtype=torch.float64)
# Iter 122; theta =  tensor([-0.8059426791, -0.3956168588,  0.4875352311], dtype=torch.float64)
# Iter 123; theta =  tensor([-0.8060423198, -0.3965786938,  0.4885710873], dtype=torch.float64)
# Iter 124; theta =  tensor([-0.8061325385, -0.3975223713,  0.4895878197], dtype=torch.float64)
# Iter 125; theta =  tensor([-0.8063175621, -0.3986497298,  0.4902573789], dtype=torch.float64)
# Iter 126; theta =  tensor([-0.8063788303, -0.3994441292,  0.4912166324], dtype=torch.float64)
# Iter 127; theta =  tensor([-0.8064741510, -0.4003576065,  0.4922963375], dtype=torch.float64)
# Iter 128; theta =  tensor([-0.8066395073, -0.4014621438,  0.4933983883], dtype=torch.float64)
# Iter 129; theta =  tensor([-0.8067231348, -0.4023193888,  0.4942074373], dtype=torch.float64)
# Iter 130; theta =  tensor([-0.8067680671, -0.4030949426,  0.4952471878], dtype=torch.float64)
# Iter 131; theta =  tensor([-0.8069546955, -0.4042909279,  0.4960297699], dtype=torch.float64)
# Iter 132; theta =  tensor([-0.8070762185, -0.4052312936,  0.4968498111], dtype=torch.float64)
# Iter 133; theta =  tensor([-0.8072579541, -0.4065120981,  0.4977147901], dtype=torch.float64)
# Iter 134; theta =  tensor([-0.8073029896, -0.4073373162,  0.4988032352], dtype=torch.float64)
# Iter 135; theta =  tensor([-0.8074574936, -0.4083870586,  0.4996640476], dtype=torch.float64)
# Iter 136; theta =  tensor([-0.8075625773, -0.4093358057,  0.5005640349], dtype=torch.float64)
# Iter 137; theta =  tensor([-0.8076728404, -0.4102332135,  0.5013800578], dtype=torch.float64)
# Iter 138; theta =  tensor([-0.8077979868, -0.4112826979,  0.5021646311], dtype=torch.float64)
# Iter 139; theta =  tensor([-0.8079655263, -0.4124010198,  0.5029764230], dtype=torch.float64)
# Iter 140; theta =  tensor([-0.8079866240, -0.4131130785,  0.5040361334], dtype=torch.float64)
# Iter 141; theta =  tensor([-0.8080777437, -0.4141139251,  0.5049962793], dtype=torch.float64)
# Iter 142; theta =  tensor([-0.8082387575, -0.4152224472,  0.5057665718], dtype=torch.float64)
# Iter 143; theta =  tensor([-0.8083158695, -0.4161020116,  0.5066919934], dtype=torch.float64)
# Iter 144; theta =  tensor([-0.8084133399, -0.4169901720,  0.5074560855], dtype=torch.float64)
# Iter 145; theta =  tensor([-0.8085268640, -0.4178572612,  0.5083150012], dtype=torch.float64)
# Iter 146; theta =  tensor([-0.8085978456, -0.4186339872,  0.5091961734], dtype=torch.float64)
# Iter 147; theta =  tensor([-0.8086521853, -0.4193127856,  0.5099466140], dtype=torch.float64)
# Iter 148; theta =  tensor([-0.8087326048, -0.4201054467,  0.5108737974], dtype=torch.float64)
# Iter 149; theta =  tensor([-0.8088212324, -0.4209449362,  0.5117472821], dtype=torch.float64)
# Iter 150; theta =  tensor([-0.8088843675, -0.4216641153,  0.5127283753], dtype=torch.float64)
# Iter 151; theta =  tensor([-0.8090073781, -0.4225942000,  0.5136025366], dtype=torch.float64)
# Iter 152; theta =  tensor([-0.8091776839, -0.4236140878,  0.5141660255], dtype=torch.float64)
# Iter 153; theta =  tensor([-0.8093058620, -0.4245687578,  0.5148101918], dtype=torch.float64)
# Iter 154; theta =  tensor([-0.8094156435, -0.4254332793,  0.5155361176], dtype=torch.float64)
# Iter 155; theta =  tensor([-0.8095529838, -0.4263977461,  0.5162162441], dtype=torch.float64)
# Iter 156; theta =  tensor([-0.8096180258, -0.4271458449,  0.5170152091], dtype=torch.float64)
# Iter 157; theta =  tensor([-0.8096804070, -0.4278493745,  0.5178999413], dtype=torch.float64)
# Iter 158; theta =  tensor([-0.8098114210, -0.4287791715,  0.5184616258], dtype=torch.float64)
# Iter 159; theta =  tensor([-0.8099273062, -0.4295976764,  0.5191642107], dtype=torch.float64)
# Iter 160; theta =  tensor([-0.8100079017, -0.4303617767,  0.5199225863], dtype=torch.float64)
# Iter 161; theta =  tensor([-0.8100479117, -0.4309428455,  0.5206678704], dtype=torch.float64)
# Iter 162; theta =  tensor([-0.8101752834, -0.4317966005,  0.5213647841], dtype=torch.float64)
# Iter 163; theta =  tensor([-0.8103090217, -0.4326850532,  0.5221188657], dtype=torch.float64)
# Iter 164; theta =  tensor([-0.8104158031, -0.4334771054,  0.5228166125], dtype=torch.float64)
# Iter 165; theta =  tensor([-0.8105160204, -0.4342627480,  0.5234232536], dtype=torch.float64)
# Iter 166; theta =  tensor([-0.8106696289, -0.4351982012,  0.5239799270], dtype=torch.float64)
# Iter 167; theta =  tensor([-0.8108112962, -0.4361155763,  0.5244711294], dtype=torch.float64)
# Iter 168; theta =  tensor([-0.8109194362, -0.4369685902,  0.5251389292], dtype=torch.float64)
# Iter 169; theta =  tensor([-0.8110237126, -0.4377330804,  0.5257318434], dtype=torch.float64)
# Iter 170; theta =  tensor([-0.8111525975, -0.4385704151,  0.5263638858], dtype=torch.float64)
# Iter 171; theta =  tensor([-0.8112443013, -0.4393141159,  0.5270442919], dtype=torch.float64)
# Iter 172; theta =  tensor([-0.8113600868, -0.4401310429,  0.5275573548], dtype=torch.float64)
# Iter 173; theta =  tensor([-0.8115028317, -0.4410030083,  0.5280687196], dtype=torch.float64)
# Iter 174; theta =  tensor([-0.8115765632, -0.4416860258,  0.5287954496], dtype=torch.float64)
# Iter 175; theta =  tensor([-0.8116624517, -0.4424026643,  0.5295234217], dtype=torch.float64)
# Iter 176; theta =  tensor([-0.8117799378, -0.4432366228,  0.5301468655], dtype=torch.float64)
# Iter 177; theta =  tensor([-0.8118784395, -0.4439702443,  0.5306209513], dtype=torch.float64)
# Iter 178; theta =  tensor([-0.8119946850, -0.4447816378,  0.5313571401], dtype=torch.float64)
# Iter 179; theta =  tensor([-0.8121078058, -0.4455887207,  0.5320522771], dtype=torch.float64)
# Iter 180; theta =  tensor([-0.8121775009, -0.4462221935,  0.5326616534], dtype=torch.float64)
# Iter 181; theta =  tensor([-0.8122889516, -0.4470094263,  0.5332798515], dtype=torch.float64)
# Iter 182; theta =  tensor([-0.8124071396, -0.4478270156,  0.5337850985], dtype=torch.float64)
# Iter 183; theta =  tensor([-0.8124817875, -0.4484985867,  0.5344613683], dtype=torch.float64)
# Iter 184; theta =  tensor([-0.8126647881, -0.4495806571,  0.5349502630], dtype=torch.float64)
# Iter 185; theta =  tensor([-0.8127725574, -0.4502957536,  0.5355053106], dtype=torch.float64)
# Iter 186; theta =  tensor([-0.8128236068, -0.4509241675,  0.5362880232], dtype=torch.float64)
# Iter 187; theta =  tensor([-0.8129385642, -0.4516604916,  0.5368067934], dtype=torch.float64)
# Iter 188; theta =  tensor([-0.8130015210, -0.4522999474,  0.5374983022], dtype=torch.float64)
# Iter 189; theta =  tensor([-0.8130675793, -0.4529017634,  0.5380713236], dtype=torch.float64)
# Iter 190; theta =  tensor([-0.8130970205, -0.4533557339,  0.5386898549], dtype=torch.float64)
# Iter 191; theta =  tensor([-0.8132209369, -0.4541301157,  0.5391955796], dtype=torch.float64)
# Iter 192; theta =  tensor([-0.8133313217, -0.4548584195,  0.5397460263], dtype=torch.float64)
# Iter 193; theta =  tensor([-0.8134315936, -0.4555875084,  0.5402132236], dtype=torch.float64)
# Iter 194; theta =  tensor([-0.8135020978, -0.4562772576,  0.5409099547], dtype=torch.float64)
# Iter 195; theta =  tensor([-0.8136054818, -0.4570335919,  0.5415219355], dtype=torch.float64)
# Iter 196; theta =  tensor([-0.8137284375, -0.4578536052,  0.5420490937], dtype=torch.float64)
# Iter 197; theta =  tensor([-0.8137923542, -0.4584574044,  0.5427236105], dtype=torch.float64)
# Iter 198; theta =  tensor([-0.8139109702, -0.4592222568,  0.5433268522], dtype=torch.float64)
# Iter 199; theta =  tensor([-0.8139654150, -0.4597840456,  0.5440121221], dtype=torch.float64)
# Iter 200; theta =  tensor([-0.8140747180, -0.4605064450,  0.5445172447], dtype=torch.float64)
# Iter 201; theta =  tensor([-0.8141578162, -0.4611762989,  0.5450520552], dtype=torch.float64)
# Iter 202; theta =  tensor([-0.8141759110, -0.4616002271,  0.5457715019], dtype=torch.float64)
# Iter 203; theta =  tensor([-0.8142413912, -0.4622770669,  0.5464857081], dtype=torch.float64)
# Iter 204; theta =  tensor([-0.8142801053, -0.4627482908,  0.5470862453], dtype=torch.float64)
# Iter 205; theta =  tensor([-0.8143401262, -0.4633069192,  0.5476201002], dtype=torch.float64)
# Iter 206; theta =  tensor([-0.8144060907, -0.4639300202,  0.5482122038], dtype=torch.float64)
# Iter 207; theta =  tensor([-0.8145414518, -0.4647627080,  0.5486870991], dtype=torch.float64)
# Iter 208; theta =  tensor([-0.8146239297, -0.4654350751,  0.5492126596], dtype=torch.float64)
# Iter 209; theta =  tensor([-0.8148228798, -0.4665196529,  0.5496671029], dtype=torch.float64)
# Iter 210; theta =  tensor([-0.8149190133, -0.4672374048,  0.5501478440], dtype=torch.float64)
# Iter 211; theta =  tensor([-0.8149880746, -0.4677848631,  0.5507612968], dtype=torch.float64)
# Iter 212; theta =  tensor([-0.8150533679, -0.4684095720,  0.5513194808], dtype=torch.float64)
# Iter 213; theta =  tensor([-0.8151594726, -0.4691086129,  0.5518351341], dtype=torch.float64)
# Iter 214; theta =  tensor([-0.8152084217, -0.4696903067,  0.5525131676], dtype=torch.float64)
# Iter 215; theta =  tensor([-0.8152700226, -0.4702735104,  0.5531682071], dtype=torch.float64)
# Iter 216; theta =  tensor([-0.8153502577, -0.4709015629,  0.5536820144], dtype=torch.float64)
# Iter 217; theta =  tensor([-0.8154246794, -0.4715624226,  0.5542643912], dtype=torch.float64)
# Iter 218; theta =  tensor([-0.8155054797, -0.4722528642,  0.5548422158], dtype=torch.float64)
# Iter 219; theta =  tensor([-0.8155621196, -0.4728371982,  0.5554879873], dtype=torch.float64)
# Iter 220; theta =  tensor([-0.8157121462, -0.4737240176,  0.5558862698], dtype=torch.float64)
# Iter 221; theta =  tensor([-0.8157758606, -0.4742630922,  0.5564453501], dtype=torch.float64)
# Iter 222; theta =  tensor([-0.8158188015, -0.4747349708,  0.5569866498], dtype=torch.float64)
# Iter 223; theta =  tensor([-0.8159002782, -0.4753208844,  0.5574764979], dtype=torch.float64)
# Iter 224; theta =  tensor([-0.8159843308, -0.4759723044,  0.5580485695], dtype=torch.float64)
# Iter 225; theta =  tensor([-0.8159970343, -0.4763718606,  0.5586879456], dtype=torch.float64)
# Iter 226; theta =  tensor([-0.8160582898, -0.4769075078,  0.5592478809], dtype=torch.float64)
# Iter 227; theta =  tensor([-0.8161291817, -0.4774819247,  0.5598644881], dtype=torch.float64)
# Iter 228; theta =  tensor([-0.8162084546, -0.4781204876,  0.5603750553], dtype=torch.float64)
# Iter 229; theta =  tensor([-0.8162590418, -0.4786077722,  0.5608963381], dtype=torch.float64)
# Iter 230; theta =  tensor([-0.8162974854, -0.4790870524,  0.5614737171], dtype=torch.float64)
# Iter 231; theta =  tensor([-0.8163215427, -0.4795193977,  0.5620727073], dtype=torch.float64)
# Iter 232; theta =  tensor([-0.8164421706, -0.4802187098,  0.5625159264], dtype=torch.float64)
# Iter 233; theta =  tensor([-0.8164891224, -0.4806835138,  0.5630830931], dtype=torch.float64)
# Iter 234; theta =  tensor([-0.8165123048, -0.4811947332,  0.5637836522], dtype=torch.float64)
# Iter 235; theta =  tensor([-0.8165756852, -0.4816488657,  0.5642442117], dtype=torch.float64)
# Iter 236; theta =  tensor([-0.8166753343, -0.4822898629,  0.5646343192], dtype=torch.float64)
# Iter 237; theta =  tensor([-0.8167417543, -0.4828177086,  0.5651264900], dtype=torch.float64)
# Iter 238; theta =  tensor([-0.8168221167, -0.4834283391,  0.5656361784], dtype=torch.float64)
# Iter 239; theta =  tensor([-0.8168572168, -0.4838818295,  0.5661359302], dtype=torch.float64)
# Iter 240; theta =  tensor([-0.8168660156, -0.4842550723,  0.5668097026], dtype=torch.float64)
# Iter 241; theta =  tensor([-0.8169439890, -0.4848049461,  0.5672509997], dtype=torch.float64)
# Iter 242; theta =  tensor([-0.8170728588, -0.4855487697,  0.5675929245], dtype=torch.float64)
# Iter 243; theta =  tensor([-0.8171568687, -0.4861486470,  0.5680254871], dtype=torch.float64)
# Iter 244; theta =  tensor([-0.8172811036, -0.4869119368,  0.5684245109], dtype=torch.float64)
# Iter 245; theta =  tensor([-0.8174266699, -0.4877140150,  0.5688075529], dtype=torch.float64)
# Iter 246; theta =  tensor([-0.8175064228, -0.4882971483,  0.5692745567], dtype=torch.float64)
# Iter 247; theta =  tensor([-0.8175818049, -0.4889408115,  0.5698310733], dtype=torch.float64)
# Iter 248; theta =  tensor([-0.8176265026, -0.4894482553,  0.5704416151], dtype=torch.float64)
# Iter 249; theta =  tensor([-0.8176521052, -0.4898706495,  0.5709772803], dtype=torch.float64)
# Iter 250; theta =  tensor([-0.8176821086, -0.4902684308,  0.5715137334], dtype=torch.float64)
# Iter 251; theta =  tensor([-0.8178137632, -0.4909740965,  0.5718264226], dtype=torch.float64)
# Iter 252; theta =  tensor([-0.8178946924, -0.4915853499,  0.5723318705], dtype=torch.float64)
# Iter 253; theta =  tensor([-0.8179847930, -0.4921930189,  0.5727053024], dtype=torch.float64)
# Iter 254; theta =  tensor([-0.8180860128, -0.4928665951,  0.5731492149], dtype=torch.float64)
# Iter 255; theta =  tensor([-0.8181462210, -0.4934035191,  0.5736916437], dtype=torch.float64)
# Iter 256; theta =  tensor([-0.8182341290, -0.4939978071,  0.5741755175], dtype=torch.float64)
# Iter 257; theta =  tensor([-0.8182966534, -0.4945935328,  0.5748182893], dtype=torch.float64)
# Iter 258; theta =  tensor([-0.8183565654, -0.4950626657,  0.5752534473], dtype=torch.float64)
# Iter 259; theta =  tensor([-0.8184293405, -0.4956251923,  0.5757620089], dtype=torch.float64)
# Iter 260; theta =  tensor([-0.8185240994, -0.4962518587,  0.5761652632], dtype=torch.float64)
# Iter 261; theta =  tensor([-0.8185965820, -0.4968465191,  0.5766441359], dtype=torch.float64)
# Iter 262; theta =  tensor([-0.8186621104, -0.4973585675,  0.5771741551], dtype=torch.float64)
# Iter 263; theta =  tensor([-0.8187144233, -0.4978843235,  0.5777040224], dtype=torch.float64)
# Iter 264; theta =  tensor([-0.8187784221, -0.4983577059,  0.5780984729], dtype=torch.float64)
# Iter 265; theta =  tensor([-0.8188716952, -0.4989622871,  0.5785203191], dtype=torch.float64)
# Iter 266; theta =  tensor([-0.8189596711, -0.4995297568,  0.5789498530], dtype=torch.float64)
# Iter 267; theta =  tensor([-0.8190325792, -0.5000990805,  0.5794124846], dtype=torch.float64)
# Iter 268; theta =  tensor([-0.8191265969, -0.5007319169,  0.5798404069], dtype=torch.float64)
# Iter 269; theta =  tensor([-0.8191643780, -0.5011862793,  0.5803959178], dtype=torch.float64)
# Iter 270; theta =  tensor([-0.8192539888, -0.5017899081,  0.5808914191], dtype=torch.float64)
# Iter 271; theta =  tensor([-0.8193429918, -0.5024168817,  0.5812950718], dtype=torch.float64)
# Iter 272; theta =  tensor([-0.8194034322, -0.5029578334,  0.5818329194], dtype=torch.float64)
# Iter 273; theta =  tensor([-0.8194612292, -0.5034076084,  0.5822734832], dtype=torch.float64)
# Iter 274; theta =  tensor([-0.8195345528, -0.5039365577,  0.5827401286], dtype=torch.float64)
# Iter 275; theta =  tensor([-0.8195812711, -0.5043766744,  0.5832019094], dtype=torch.float64)
# Iter 276; theta =  tensor([-0.8196612794, -0.5049074068,  0.5836557323], dtype=torch.float64)
# Iter 277; theta =  tensor([-0.8197525495, -0.5055051841,  0.5840316156], dtype=torch.float64)
# Iter 278; theta =  tensor([-0.8198177886, -0.5059898508,  0.5844430205], dtype=torch.float64)
# Iter 279; theta =  tensor([-0.8199049573, -0.5065361222,  0.5848240209], dtype=torch.float64)
# Iter 280; theta =  tensor([-0.8199957211, -0.5071251984,  0.5852075837], dtype=torch.float64)
# Iter 281; theta =  tensor([-0.8200547980, -0.5075674915,  0.5856481647], dtype=torch.float64)
# Iter 282; theta =  tensor([-0.8201165674, -0.5080872865,  0.5860844389], dtype=torch.float64)
# Iter 283; theta =  tensor([-0.8201706485, -0.5085745510,  0.5866127236], dtype=torch.float64)
# Iter 284; theta =  tensor([-0.8202281979, -0.5090489936,  0.5870375752], dtype=torch.float64)
# Iter 285; theta =  tensor([-0.8202692976, -0.5094310220,  0.5874844287], dtype=torch.float64)
# Iter 286; theta =  tensor([-0.8203261983, -0.5099305234,  0.5878952708], dtype=torch.float64)
# Iter 287; theta =  tensor([-0.8204350421, -0.5105477112,  0.5881834098], dtype=torch.float64)
# Iter 288; theta =  tensor([-0.8205514134, -0.5112160964,  0.5885080718], dtype=torch.float64)
# Iter 289; theta =  tensor([-0.8206396168, -0.5117969982,  0.5889095720], dtype=torch.float64)
# Iter 290; theta =  tensor([-0.8207009560, -0.5122882856,  0.5893794762], dtype=torch.float64)
# Iter 291; theta =  tensor([-0.8207157241, -0.5125551931,  0.5898231217], dtype=torch.float64)
# Iter 292; theta =  tensor([-0.8208012087, -0.5131729125,  0.5902488904], dtype=torch.float64)
# Iter 293; theta =  tensor([-0.8208611380, -0.5136596826,  0.5906556043], dtype=torch.float64)
# Iter 294; theta =  tensor([-0.8209525113, -0.5142412027,  0.5909684224], dtype=torch.float64)
# Iter 295; theta =  tensor([-0.8210364264, -0.5147951089,  0.5913051581], dtype=torch.float64)
# Iter 296; theta =  tensor([-0.8211052606, -0.5153000732,  0.5917743772], dtype=torch.float64)
# Iter 297; theta =  tensor([-0.8211459018, -0.5157030441,  0.5923233538], dtype=torch.float64)
# Iter 298; theta =  tensor([-0.8212035805, -0.5162125166,  0.5927882790], dtype=torch.float64)
# Iter 299; theta =  tensor([-0.8212971289, -0.5168147495,  0.5932201039], dtype=torch.float64)
# Iter 300; theta =  tensor([-0.8213306980, -0.5172064046,  0.5936429838], dtype=torch.float64)
# Iter 301; theta =  tensor([-0.8213845926, -0.5176749419,  0.5940689850], dtype=torch.float64)
# Iter 302; theta =  tensor([-0.8214903925, -0.5182849652,  0.5943894433], dtype=torch.float64)
# Iter 303; theta =  tensor([-0.8215570036, -0.5187948427,  0.5947826389], dtype=torch.float64)
# Iter 304; theta =  tensor([-0.8216041199, -0.5191843570,  0.5952085689], dtype=torch.float64)
# Iter 305; theta =  tensor([-0.8217008992, -0.5197733814,  0.5956631075], dtype=torch.float64)
# Iter 306; theta =  tensor([-0.8218241937, -0.5204501883,  0.5959434194], dtype=torch.float64)
# Iter 307; theta =  tensor([-0.8218941055, -0.5209366757,  0.5963107337], dtype=torch.float64)
# Iter 308; theta =  tensor([-0.8219700553, -0.5214298831,  0.5966885518], dtype=torch.float64)
# Iter 309; theta =  tensor([-0.8219789280, -0.5216956143,  0.5971554379], dtype=torch.float64)
# Iter 310; theta =  tensor([-0.8220669939, -0.5221973292,  0.5974694725], dtype=torch.float64)
# Iter 311; theta =  tensor([-0.8221714318, -0.5228207061,  0.5978530670], dtype=torch.float64)
# Iter 312; theta =  tensor([-0.8222051080, -0.5231857258,  0.5982611055], dtype=torch.float64)
# Iter 313; theta =  tensor([-0.8222849472, -0.5237113066,  0.5985900647], dtype=torch.float64)
# Iter 314; theta =  tensor([-0.8223988846, -0.5243529501,  0.5988522962], dtype=torch.float64)
# Iter 315; theta =  tensor([-0.8224526614, -0.5247711755,  0.5992120543], dtype=torch.float64)
# Iter 316; theta =  tensor([-0.8225014536, -0.5252068947,  0.5996819341], dtype=torch.float64)
# Iter 317; theta =  tensor([-0.8225317419, -0.5256079867,  0.6001716719], dtype=torch.float64)
# Iter 318; theta =  tensor([-0.8226056050, -0.5260967058,  0.6005180417], dtype=torch.float64)
# Iter 319; theta =  tensor([-0.8226524102, -0.5264849530,  0.6009035497], dtype=torch.float64)
# Iter 320; theta =  tensor([-0.8227131123, -0.5269161194,  0.6012797586], dtype=torch.float64)
# Iter 321; theta =  tensor([-0.8227702252, -0.5273487314,  0.6016606984], dtype=torch.float64)
# Iter 322; theta =  tensor([-0.8228149105, -0.5277413959,  0.6020076469], dtype=torch.float64)
# Iter 323; theta =  tensor([-0.8229324915, -0.5284133213,  0.6022909287], dtype=torch.float64)
# Iter 324; theta =  tensor([-0.8229701974, -0.5287627170,  0.6026428520], dtype=torch.float64)
# Iter 325; theta =  tensor([-0.8230418320, -0.5292571461,  0.6030237335], dtype=torch.float64)
# Iter 326; theta =  tensor([-0.8230901406, -0.5296992020,  0.6034314770], dtype=torch.float64)
# Iter 327; theta =  tensor([-0.8231490114, -0.5301425708,  0.6037514982], dtype=torch.float64)
# Iter 328; theta =  tensor([-0.8232437187, -0.5306796246,  0.6040282304], dtype=torch.float64)
# Iter 329; theta =  tensor([-0.8233353804, -0.5312420266,  0.6043346044], dtype=torch.float64)
# Iter 330; theta =  tensor([-0.8234086789, -0.5317208679,  0.6047081160], dtype=torch.float64)
# Iter 331; theta =  tensor([-0.8234397155, -0.5320767145,  0.6051255569], dtype=torch.float64)
# Iter 332; theta =  tensor([-0.8234828791, -0.5324880890,  0.6055492084], dtype=torch.float64)
# Iter 333; theta =  tensor([-0.8235651662, -0.5330187807,  0.6058098720], dtype=torch.float64)
# Iter 334; theta =  tensor([-0.8236349162, -0.5334611390,  0.6061317614], dtype=torch.float64)
# Iter 335; theta =  tensor([-0.8236912014, -0.5339212260,  0.6065215095], dtype=torch.float64)
# Iter 336; theta =  tensor([-0.8237294646, -0.5342997310,  0.6069525758], dtype=torch.float64)
# Iter 337; theta =  tensor([-0.8237984236, -0.5347425525,  0.6072759049], dtype=torch.float64)
# Iter 338; theta =  tensor([-0.8238586892, -0.5352090943,  0.6076604071], dtype=torch.float64)
# Iter 339; theta =  tensor([-0.8239324830, -0.5356437624,  0.6079543571], dtype=torch.float64)
# Iter 340; theta =  tensor([-0.8239916563, -0.5360780944,  0.6082721912], dtype=torch.float64)
# Iter 341; theta =  tensor([-0.8240840440, -0.5366171073,  0.6085923008], dtype=torch.float64)
# Iter 342; theta =  tensor([-0.8241136487, -0.5369812842,  0.6090354027], dtype=torch.float64)
# Iter 343; theta =  tensor([-0.8241845860, -0.5374600390,  0.6093064924], dtype=torch.float64)
# Iter 344; theta =  tensor([-0.8242080672, -0.5377927569,  0.6097195948], dtype=torch.float64)
# Iter 345; theta =  tensor([-0.8242489241, -0.5381228127,  0.6100247928], dtype=torch.float64)
# Iter 346; theta =  tensor([-0.8242952206, -0.5385120729,  0.6103695457], dtype=torch.float64)
# Iter 347; theta =  tensor([-0.8243328125, -0.5388857339,  0.6107800479], dtype=torch.float64)
# Iter 348; theta =  tensor([-0.8243575795, -0.5391728816,  0.6111465562], dtype=torch.float64)
# Iter 349; theta =  tensor([-0.8244033731, -0.5395772075,  0.6115519727], dtype=torch.float64)
# Iter 350; theta =  tensor([-0.8244698953, -0.5400055513,  0.6118238889], dtype=torch.float64)
# Iter 351; theta =  tensor([-0.8245251682, -0.5403954648,  0.6121084607], dtype=torch.float64)
# Iter 352; theta =  tensor([-0.8245833381, -0.5408322764,  0.6123982274], dtype=torch.float64)
# Iter 353; theta =  tensor([-0.8246180203, -0.5411694237,  0.6127221608], dtype=torch.float64)
# Iter 354; theta =  tensor([-0.8247185729, -0.5417401457,  0.6129601975], dtype=torch.float64)
# Iter 355; theta =  tensor([-0.8248138847, -0.5422990688,  0.6132961601], dtype=torch.float64)
# Iter 356; theta =  tensor([-0.8248631540, -0.5427319439,  0.6136926951], dtype=torch.float64)
# Iter 357; theta =  tensor([-0.8249334699, -0.5432063098,  0.6140310897], dtype=torch.float64)
# Iter 358; theta =  tensor([-0.8250051264, -0.5436859783,  0.6142950705], dtype=torch.float64)
# Iter 359; theta =  tensor([-0.8250559550, -0.5440686093,  0.6146323688], dtype=torch.float64)
# Iter 360; theta =  tensor([-0.8251070017, -0.5444204732,  0.6150087576], dtype=torch.float64)
# Iter 361; theta =  tensor([-0.8251515699, -0.5448128087,  0.6153839420], dtype=torch.float64)
# Iter 362; theta =  tensor([-0.8252029038, -0.5452191308,  0.6157491113], dtype=torch.float64)
# Iter 363; theta =  tensor([-0.8253019511, -0.5457901951,  0.6160067837], dtype=torch.float64)
# Iter 364; theta =  tensor([-0.8253581445, -0.5461790123,  0.6162846610], dtype=torch.float64)
# Iter 365; theta =  tensor([-0.8254005175, -0.5465060994,  0.6166012459], dtype=torch.float64)
# Iter 366; theta =  tensor([-0.8254578392, -0.5469344595,  0.6168910924], dtype=torch.float64)
# Iter 367; theta =  tensor([-0.8254838442, -0.5472546300,  0.6172615013], dtype=torch.float64)
# Iter 368; theta =  tensor([-0.8255355417, -0.5476709996,  0.6176400309], dtype=torch.float64)
# Iter 369; theta =  tensor([-0.8256076661, -0.5481225985,  0.6179613637], dtype=torch.float64)
# Iter 370; theta =  tensor([-0.8257069528, -0.5486724854,  0.6182304326], dtype=torch.float64)
# Iter 371; theta =  tensor([-0.8257938238, -0.5491625181,  0.6184944247], dtype=torch.float64)
# Iter 372; theta =  tensor([-0.8258627354, -0.5495654497,  0.6187418401], dtype=torch.float64)
# Iter 373; theta =  tensor([-0.8259445010, -0.5500199164,  0.6191007524], dtype=torch.float64)
# Iter 374; theta =  tensor([-0.8259754385, -0.5503336321,  0.6194504476], dtype=torch.float64)
# Iter 375; theta =  tensor([-0.8260395102, -0.5507740100,  0.6197330168], dtype=torch.float64)
# Iter 376; theta =  tensor([-0.8260671104, -0.5511275887,  0.6201411988], dtype=torch.float64)
# Iter 377; theta =  tensor([-0.8261129357, -0.5514922957,  0.6204706914], dtype=torch.float64)
# Iter 378; theta =  tensor([-0.8261977932, -0.5519913833,  0.6206991673], dtype=torch.float64)
# Iter 379; theta =  tensor([-0.8262401955, -0.5523596230,  0.6210498178], dtype=torch.float64)
# Iter 380; theta =  tensor([-0.8262745596, -0.5526589640,  0.6213503371], dtype=torch.float64)
# Iter 381; theta =  tensor([-0.8263411956, -0.5530905127,  0.6216231058], dtype=torch.float64)
# Iter 382; theta =  tensor([-0.8263786628, -0.5534702603,  0.6220251802], dtype=torch.float64)
# Iter 383; theta =  tensor([-0.8264078846, -0.5537628290,  0.6224144151], dtype=torch.float64)
# Iter 384; theta =  tensor([-0.8264618167, -0.5541645663,  0.6227548038], dtype=torch.float64)
# Iter 385; theta =  tensor([-0.8265503752, -0.5546626913,  0.6229856933], dtype=torch.float64)
# Iter 386; theta =  tensor([-0.8266356509, -0.5551375447,  0.6232342610], dtype=torch.float64)
# Iter 387; theta =  tensor([-0.8266548454, -0.5554007725,  0.6235999614], dtype=torch.float64)
# Iter 388; theta =  tensor([-0.8267171842, -0.5558391066,  0.6238922562], dtype=torch.float64)
# Iter 389; theta =  tensor([-0.8267750640, -0.5562713359,  0.6242043308], dtype=torch.float64)
# Iter 390; theta =  tensor([-0.8268351228, -0.5566912390,  0.6245812845], dtype=torch.float64)
# Iter 391; theta =  tensor([-0.8269059381, -0.5571330213,  0.6249513343], dtype=torch.float64)
# Iter 392; theta =  tensor([-0.8269328211, -0.5574098743,  0.6253009899], dtype=torch.float64)
# Iter 393; theta =  tensor([-0.8270109259, -0.5578431188,  0.6255400006], dtype=torch.float64)
# Iter 394; theta =  tensor([-0.8270764276, -0.5582823763,  0.6258623455], dtype=torch.float64)
# Iter 395; theta =  tensor([-0.8271327134, -0.5586466871,  0.6260909126], dtype=torch.float64)
# Iter 396; theta =  tensor([-0.8271724528, -0.5589555275,  0.6264113605], dtype=torch.float64)
# Iter 397; theta =  tensor([-0.8272633248, -0.5594703410,  0.6265984768], dtype=torch.float64)
# Iter 398; theta =  tensor([-0.8272883630, -0.5597207236,  0.6269082706], dtype=torch.float64)
# Iter 399; theta =  tensor([-0.8273725044, -0.5601795457,  0.6271079512], dtype=torch.float64)
# Iter 400; theta =  tensor([-0.8274636024, -0.5606573975,  0.6273827476], dtype=torch.float64)
# Iter 401; theta =  tensor([-0.8274715830, -0.5608857869,  0.6277632915], dtype=torch.float64)
# Iter 402; theta =  tensor([-0.8275112693, -0.5611845710,  0.6280872479], dtype=torch.float64)
# Iter 403; theta =  tensor([-0.8275663195, -0.5615423577,  0.6283638856], dtype=torch.float64)
# Iter 404; theta =  tensor([-0.8276086997, -0.5618522342,  0.6286136232], dtype=torch.float64)
# Iter 405; theta =  tensor([-0.8276625718, -0.5623033388,  0.6289424062], dtype=torch.float64)
# Iter 406; theta =  tensor([-0.8277544690, -0.5627987132,  0.6291674677], dtype=torch.float64)
# Iter 407; theta =  tensor([-0.8277756963, -0.5630770580,  0.6294974974], dtype=torch.float64)
# Iter 408; theta =  tensor([-0.8278701800, -0.5636046107,  0.6297775833], dtype=torch.float64)
# Iter 409; theta =  tensor([-0.8279347985, -0.5639959741,  0.6300154967], dtype=torch.float64)
# Iter 410; theta =  tensor([-0.8279881969, -0.5643630462,  0.6302338029], dtype=torch.float64)
# Iter 411; theta =  tensor([-0.8280067910, -0.5646335505,  0.6306174913], dtype=torch.float64)
# Iter 412; theta =  tensor([-0.8280571657, -0.5649865457,  0.6309274955], dtype=torch.float64)
# Iter 413; theta =  tensor([-0.8281185709, -0.5654202549,  0.6312422657], dtype=torch.float64)
# Iter 414; theta =  tensor([-0.8281901855, -0.5658717920,  0.6314534631], dtype=torch.float64)

# %%
y_p = logistica_prever(Xn, theta)
print(y == y_p.int().double())
print((y == y_p.int().double()).double().mean())
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True])
# tensor(1., dtype=torch.float64)
